# %%
import numpy as np
import netCDF4
import pandas as pd
import os

# %%
netcdf_dir='C:\\Shaukat\\code\\data_rep\\gfs\\planetos\\'
filelist=[] 
filename=[]

for file in os.listdir(netcdf_dir):
    if file.endswith(".nc"):
        #print(os.path.join(netcdf_dir, file))
        filelist.append(os.path.join(netcdf_dir, file))
        filename.append(file)


#######
# Sort
#######
print(filelist)
print(filename)

########################
# Pooley's coordinates:
#######################
lat = 131 # lat = -42.7402114
lon = 142 # lon = 147.4260221
lat_val = -42.7402114
lon_val = 147.4260221
# Out:
# ['C:\\Shaukat\\code\\data_rep\\gfs\\planetos\\H_2017-08-21T180000.nc']
# ['H_2017-08-21T180000.nc']

# %%
for _id,_file in enumerate(filelist):
    
    #####################
    # Filename for report
    #####################
    filename_string = filename[_id]
    filename_string = filename_string.split('.')[0]
    filename_string = filename_string + "_lat_" + str(lat_val) + "_lon_" + str(lon_val) + ".csv"
    print('Start examining file: {}'.format(_file))
    
    # Read File 
    gfs = netCDF4.Dataset(_file)

    # Init Dataframe for description
    df_description = pd.DataFrame()
    
    #########################################
    # Examining single variable
    #########################################

    var_name='acpcpsfc_1_Hour_Accumulation' #CHANGE THIS
    acpcpsfc_1_Hour_Accumulation = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS

    # Read this variable in a dataframe
    df = pd.DataFrame()
    df[var_name] = acpcpsfc_1_Hour_Accumulation # CHANGE THIS

    # Get the statistics of this dataframe
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = df_curr_descr.copy()
    del df_curr_descr, df, acpcpsfc_1_Hour_Accumulation
    
    #########################################
    # Examining single variable
    #########################################

    var_name='lhtflsfc_1_Hour_Average' #CHANGE THIS
    lhtflsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS

    # Read this variable in a dataframe
    df = pd.DataFrame()
    df[var_name] = lhtflsfc_1_Hour_Average # CHANGE THIS

    # Get the statistics of this dataframe
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, lhtflsfc_1_Hour_Average

    #########################################
    # Examining single variable
    #########################################

    var_name='pratesfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    pratesfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = pratesfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, pratesfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='shtflsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    shtflsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = shtflsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, shtflsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcclm_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    tcdcclm_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdcclm_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdcclm_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='tcdclcll_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    tcdclcll_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdclcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdclcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcmcll_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    tcdcmcll_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdcmcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdcmcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='tcdchcll_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    tcdchcll_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdchcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdchcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcblcll_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    tcdcblcll_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdcblcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdcblcll_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='apcpsfc_1_Hour_Accumulation' #CHANGE THIS (copy/paste $var_name)
    apcpsfc_1_Hour_Accumulation = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = apcpsfc_1_Hour_Accumulation #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del apcpsfc_1_Hour_Accumulation #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='crainsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    crainsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = crainsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del crainsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='cfrzrsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    cfrzrsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = cfrzrsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del cfrzrsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='cicepsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    cicepsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = cicepsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del cicepsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='csnowsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    csnowsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = csnowsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del csnowsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='cpratsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    cpratsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = cpratsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del cpratsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='dswrfsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    dswrfsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = dswrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del dswrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='uswrfsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    uswrfsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = uswrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del uswrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='dlwrfsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    dlwrfsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = dlwrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del dlwrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='ulwrfsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    ulwrfsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = ulwrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del ulwrfsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='gfluxsfc_1_Hour_Average' #CHANGE THIS (copy/paste $var_name)
    gfluxsfc_1_Hour_Average = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = gfluxsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del gfluxsfc_1_Hour_Average #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='watrsfc_1_Hour_Accumulation' #CHANGE THIS (copy/paste $var_name)
    watrsfc_1_Hour_Accumulation = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = watrsfc_1_Hour_Accumulation #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del watrsfc_1_Hour_Accumulation #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='tsoil' #CHANGE THIS (copy/paste $var_name)
    tsoil = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tsoil #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tsoil #CHANGE THIS (copy/paste $var_name)

    #########################################
    # Examining single variable
    #########################################

    var_name='soilw_cm' #CHANGE THIS (copy/paste $var_name)
    soilw_cm = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = soilw_cm #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del soilw_cm #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='ugrd_m' #CHANGE THIS (copy/paste $var_name)
    ugrd_m = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = ugrd_m #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del ugrd_m #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='vgrd_m' #CHANGE THIS (copy/paste $var_name)
    vgrd_m = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = vgrd_m #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del vgrd_m #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='hindexsfc' #CHANGE THIS (copy/paste $var_name)
    hindexsfc = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = hindexsfc #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del hindexsfc #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='icecsfc' #CHANGE THIS (copy/paste $var_name)
    icecsfc = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = icecsfc #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del icecsfc #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='pressfc' #CHANGE THIS (copy/paste $var_name)
    pressfc = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = pressfc #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del pressfc #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='tmpsfc' #CHANGE THIS (copy/paste $var_name)
    tmpsfc = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tmpsfc #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tmpsfc #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcccll' #CHANGE THIS (copy/paste $var_name)
    tcdcccll = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = tcdcccll #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del tcdcccll #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='pevprsfc' #CHANGE THIS (copy/paste $var_name)
    pevprsfc = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = pevprsfc #CHANGE THIS (copy/paste $var_name)

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df
    del pevprsfc #CHANGE THIS (copy/paste $var_name)


    #########################################
    # Examining single variable
    #########################################

    var_name='sunsdsfc' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name

    #########################################
    # Examining single variable
    #########################################

    var_name='wiltsfc' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name

    #########################################
    # Examining single variable
    #########################################

    var_name='gustsfc' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='dpt2m' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name

    #########################################
    # Examining single variable
    #########################################

    var_name='rh2m' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tmp_m' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,0,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='acpcpsfc_3_Hour_Accumulation' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='lhtflsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='pratesfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='shtflsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcclm_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdclcll_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcmcll_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdchcll_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='tcdcblcll_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='apcpsfc_3_Hour_Accumulation' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='crainsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='cfrzrsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='cicepsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name

    #########################################
    # Examining single variable
    #########################################
    var_name='csnowsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################
    var_name='cpratsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='dswrfsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='uswrfsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################
    var_name='dlwrfsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='ulwrfsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='gfluxsfc_3_Hour_Average' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    #########################################
    # Examining single variable
    #########################################

    var_name='watrsfc_3_Hour_Accumulation' #CHANGE THIS (copy/paste $var_name)

    ####################################
    # Read this variable in a dataframe
    ####################################
    df = pd.DataFrame()
    df[var_name] = np.array(gfs.variables[var_name][:,lat,lon]) #CHANGE indexing if needed

    #######################################
    # Get the statistics of this dataframe
    ######################################
    df_curr_descr = df.describe()
    df_curr_descr.loc['NaN'] = sum(df[var_name].isnull() == True).astype('int')
    df_description = pd.concat( [df_description, df_curr_descr], axis = 1)
    del df_curr_descr, df, var_name


    
    ############################
    # Writing to csv
    ############################
    df_description.to_csv(filename_string)
    print('Finished examining file: {}'.format(_file))
    print('Report is generated as csv in: {}'.format(filename_string))
    del filename_string
# Out:
# Start examining file: C:\Shaukat\code\data_rep\gfs\planetos\H_2017-08-21T180000.nc
# Finished examining file: C:\Shaukat\code\data_rep\gfs\planetos\H_2017-08-21T180000.nc
# Report is generated as csv in: H_2017-08-21T180000_lat_-42.7402114_lon_147.4260221.csv
