# %%
# Run it once and Comment
# import sys
# sys.path.append('C:\\Shaukat\\code\\functions_implemented')
# print sys.path
# import functions_implemented as fi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
import scipy.stats as stats
from datetime import datetime, timedelta

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau
from keras.layers.recurrent import LSTM

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from copy import deepcopy

from keras.models import load_model

# %matplotlib inline
# Out:
# Using Theano backend.

# %%
df_gfs = pd.read_csv("C://Shaukat//code//data_rep//gfs//csv_files//gfs_orford_clipped.csv")
df_bom = pd.read_csv("C://Shaukat//code//data_rep//bom//Orford.csv")

# %%
# Setting up GFS
df_gfs['Unnamed: 0'] = pd.to_datetime(df_gfs['Unnamed: 0'])
df_gfs.set_index('Unnamed: 0', inplace = True)

# Setting up BOM
# df_bom['date_only'] = df_bom.UtcTime.dt.date
df_bom.UtcTime = pd.to_datetime(df_bom.UtcTime)
df_bom.set_index('UtcTime', inplace=True)

# Trim df_bom and df_gfs from november 2016
df_bom = df_bom.loc['2016-09-08 00:00:00':]
df_gfs = df_gfs.loc['2016-09-08 00:00:00':]

# %%
# df_gfs

# %%
# df_bom

# %%
# Prepare groundtruth dataframe from BOM 
tot_gfs_entries = len(df_gfs.index)
df_gt = pd.DataFrame(index=df_gfs.index, columns=['rainfall_t+1','rainfall_t+2','rainfall_t+3'])
for dt_gfs in range(0,tot_gfs_entries):
    # Iterate each date in GFS and get the groundtruth rainfall from BOM
    
    date_a = df_gfs.index[dt_gfs] # Forecast time in gfs (made every three hours)
    date_t1 = date_a + timedelta(hours=1) # rainfall_t+1
    date_t2 = date_a + timedelta(hours=2) # rainfall_t+2
    date_t3 = date_a + timedelta(hours=3) # rainfall_t+3
    print 'processing: ', date_a 

    # df_patch for t+1 (Gather groundtruth rainfall from BOM)
    df_patch = df_bom.loc[date_a:date_t1].copy()
    rainfall_t1 = df_patch.RainfallLast10Minutes.sum()
    print 'date_t1: ', date_t1 

    
    # df_patch for t+2 (Gather groundtruth rainfall from BOM)
    df_patch = df_bom.loc[date_t1:date_t2].copy()
    rainfall_t2 = df_patch.RainfallLast10Minutes.sum()
    print 'date_t2: ', date_t2 

    
    # df_patch for t+3 (Gather groundtruth rainfall from BOM)
    df_patch = df_bom.loc[date_t2:date_t3].copy()
    rainfall_t3 = df_patch.RainfallLast10Minutes.sum()
    print 'date_t3: ', date_t3, '\n' 

    
    # Add it to the groundtruth df
    df_gt.loc[date_a] = [rainfall_t1, rainfall_t2, rainfall_t3]
    
    # Delete variables
    del date_a
    del date_t1
    del date_t2
    del date_t3
    del rainfall_t1
    del rainfall_t2
    del rainfall_t3
# Out:
# processing:  2016-09-08 00:00:00
# date_t1:  2016-09-08 01:00:00
# date_t2:  2016-09-08 02:00:00
# date_t3:  2016-09-08 03:00:00
#
# processing:  2016-09-08 03:00:00
# date_t1:  2016-09-08 04:00:00
# date_t2:  2016-09-08 05:00:00
# date_t3:  2016-09-08 06:00:00
#
# processing:  2016-09-08 06:00:00
# date_t1:  2016-09-08 07:00:00
# date_t2:  2016-09-08 08:00:00
# date_t3:  2016-09-08 09:00:00
#
# processing:  2016-09-08 09:00:00
# date_t1:  2016-09-08 10:00:00
# date_t2:  2016-09-08 11:00:00
# date_t3:  2016-09-08 12:00:00
#
# processing:  2016-09-08 12:00:00
# date_t1:  2016-09-08 13:00:00
# date_t2:  2016-09-08 14:00:00
# date_t3:  2016-09-08 15:00:00
#
# processing:  2016-09-08 15:00:00
# date_t1:  2016-09-08 16:00:00
# date_t2:  2016-09-08 17:00:00
# date_t3:  2016-09-08 18:00:00
#
# processing:  2016-09-08 18:00:00
# date_t1:  2016-09-08 19:00:00
# date_t2:  2016-09-08 20:00:00
# date_t3:  2016-09-08 21:00:00
#
# processing:  2016-09-08 21:00:00
# date_t1:  2016-09-08 22:00:00
# date_t2:  2016-09-08 23:00:00
# date_t3:  2016-09-09 00:00:00
#
# processing:  2016-09-09 00:00:00
# date_t1:  2016-09-09 01:00:00
# date_t2:  2016-09-09 02:00:00
# date_t3:  2016-09-09 03:00:00
#
# processing:  2016-09-09 03:00:00
# date_t1:  2016-09-09 04:00:00
# date_t2:  2016-09-09 05:00:00
# date_t3:  2016-09-09 06:00:00
#
# processing:  2016-09-09 06:00:00
# date_t1:  2016-09-09 07:00:00
# date_t2:  2016-09-09 08:00:00
# date_t3:  2016-09-09 09:00:00
#
# processing:  2016-09-09 09:00:00
# date_t1:  2016-09-09 10:00:00
# date_t2:  2016-09-09 11:00:00
# date_t3:  2016-09-09 12:00:00
#
# processing:  2016-09-09 12:00:00
# date_t1:  2016-09-09 13:00:00
# date_t2:  2016-09-09 14:00:00
# date_t3:  2016-09-09 15:00:00
#
# processing:  2016-09-09 15:00:00
# date_t1:  2016-09-09 16:00:00
# date_t2:  2016-09-09 17:00:00
# date_t3:  2016-09-09 18:00:00
#
# processing:  2016-09-09 18:00:00
# date_t1:  2016-09-09 19:00:00
# date_t2:  2016-09-09 20:00:00
# date_t3:  2016-09-09 21:00:00
#
# processing:  2016-09-09 21:00:00
# date_t1:  2016-09-09 22:00:00
# date_t2:  2016-09-09 23:00:00
# date_t3:  2016-09-10 00:00:00
#
# processing:  2016-09-10 00:00:00
# date_t1:  2016-09-10 01:00:00
# date_t2:  2016-09-10 02:00:00
# date_t3:  2016-09-10 03:00:00
#
# processing:  2016-09-10 03:00:00
# date_t1:  2016-09-10 04:00:00
# date_t2:  2016-09-10 05:00:00
# date_t3:  2016-09-10 06:00:00
#
# processing:  2016-09-10 06:00:00
# date_t1:  2016-09-10 07:00:00
# date_t2:  2016-09-10 08:00:00
# date_t3:  2016-09-10 09:00:00
#
# processing:  2016-09-10 09:00:00
# date_t1:  2016-09-10 10:00:00
# date_t2:  2016-09-10 11:00:00
# date_t3:  2016-09-10 12:00:00
#
# processing:  2016-09-10 12:00:00
# date_t1:  2016-09-10 13:00:00
# date_t2:  2016-09-10 14:00:00
# date_t3:  2016-09-10 15:00:00
#
# processing:  2016-09-10 15:00:00
# date_t1:  2016-09-10 16:00:00
# date_t2:  2016-09-10 17:00:00
# date_t3:  2016-09-10 18:00:00
#
# processing:  2016-09-10 18:00:00
# date_t1:  2016-09-10 19:00:00
# date_t2:  2016-09-10 20:00:00
# date_t3:  2016-09-10 21:00:00
#
# processing:  2016-09-10 21:00:00
# date_t1:  2016-09-10 22:00:00
# date_t2:  2016-09-10 23:00:00
# date_t3:  2016-09-11 00:00:00
#
# processing:  2016-09-11 00:00:00
# date_t1:  2016-09-11 01:00:00
# date_t2:  2016-09-11 02:00:00
# date_t3:  2016-09-11 03:00:00
#
# processing:  2016-09-11 03:00:00
# date_t1:  2016-09-11 04:00:00
# date_t2:  2016-09-11 05:00:00
# date_t3:  2016-09-11 06:00:00
#
# processing:  2016-09-11 06:00:00
# date_t1:  2016-09-11 07:00:00
# date_t2:  2016-09-11 08:00:00
# date_t3:  2016-09-11 09:00:00
#
# processing:  2016-09-11 09:00:00
# date_t1:  2016-09-11 10:00:00
# date_t2:  2016-09-11 11:00:00
# date_t3:  2016-09-11 12:00:00
#
# processing:  2016-09-11 12:00:00
# date_t1:  2016-09-11 13:00:00
# date_t2:  2016-09-11 14:00:00
# date_t3:  2016-09-11 15:00:00
#
# processing:  2016-09-11 15:00:00
# date_t1:  2016-09-11 16:00:00
# date_t2:  2016-09-11 17:00:00
# date_t3:  2016-09-11 18:00:00
#
# processing:  2016-09-11 18:00:00
# date_t1:  2016-09-11 19:00:00
# date_t2:  2016-09-11 20:00:00
# date_t3:  2016-09-11 21:00:00
#
# processing:  2016-09-11 21:00:00
# date_t1:  2016-09-11 22:00:00
# date_t2:  2016-09-11 23:00:00
# date_t3:  2016-09-12 00:00:00
#
# processing:  2016-09-12 00:00:00
# date_t1:  2016-09-12 01:00:00
# date_t2:  2016-09-12 02:00:00
# date_t3:  2016-09-12 03:00:00
#
# processing:  2016-09-12 03:00:00
# date_t1:  2016-09-12 04:00:00
# date_t2:  2016-09-12 05:00:00
# date_t3:  2016-09-12 06:00:00
#
# processing:  2016-09-12 06:00:00
# date_t1:  2016-09-12 07:00:00
# date_t2:  2016-09-12 08:00:00
# date_t3:  2016-09-12 09:00:00
#
# processing:  2016-09-12 09:00:00
# date_t1:  2016-09-12 10:00:00
# date_t2:  2016-09-12 11:00:00
# date_t3:  2016-09-12 12:00:00
#
# processing:  2016-09-12 12:00:00
# date_t1:  2016-09-12 13:00:00
# date_t2:  2016-09-12 14:00:00
# date_t3:  2016-09-12 15:00:00
#
# processing:  2016-09-12 15:00:00
# date_t1:  2016-09-12 16:00:00
# date_t2:  2016-09-12 17:00:00
# date_t3:  2016-09-12 18:00:00
#
# processing:  2016-09-12 18:00:00
# date_t1:  2016-09-12 19:00:00
# date_t2:  2016-09-12 20:00:00
# date_t3:  2016-09-12 21:00:00
#
# processing:  2016-09-12 21:00:00
# date_t1:  2016-09-12 22:00:00
# date_t2:  2016-09-12 23:00:00
# date_t3:  2016-09-13 00:00:00
#
# processing:  2016-09-13 00:00:00
# date_t1:  2016-09-13 01:00:00
# date_t2:  2016-09-13 02:00:00
# date_t3:  2016-09-13 03:00:00
#
# processing:  2016-09-13 03:00:00
# date_t1:  2016-09-13 04:00:00
# date_t2:  2016-09-13 05:00:00
# date_t3:  2016-09-13 06:00:00
#
# processing:  2016-09-13 06:00:00
# date_t1:  2016-09-13 07:00:00
# date_t2:  2016-09-13 08:00:00
# date_t3:  2016-09-13 09:00:00
#
# processing:  2016-09-13 09:00:00
# date_t1:  2016-09-13 10:00:00
# date_t2:  2016-09-13 11:00:00
# date_t3:  2016-09-13 12:00:00
#
# processing:  2016-09-13 12:00:00
# date_t1:  2016-09-13 13:00:00
# date_t2:  2016-09-13 14:00:00
# date_t3:  2016-09-13 15:00:00
#
# processing:  2016-09-13 15:00:00
# date_t1:  2016-09-13 16:00:00
# date_t2:  2016-09-13 17:00:00
# date_t3:  2016-09-13 18:00:00
#
# processing:  2016-09-13 18:00:00
# date_t1:  2016-09-13 19:00:00
# date_t2:  2016-09-13 20:00:00
# date_t3:  2016-09-13 21:00:00
#
# processing:  2016-09-13 21:00:00
# date_t1:  2016-09-13 22:00:00
# date_t2:  2016-09-13 23:00:00
# date_t3:  2016-09-14 00:00:00
#
# processing:  2016-09-14 00:00:00
# date_t1:  2016-09-14 01:00:00
# date_t2:  2016-09-14 02:00:00
# date_t3:  2016-09-14 03:00:00
#
# processing:  2016-09-14 03:00:00
# date_t1:  2016-09-14 04:00:00
# date_t2:  2016-09-14 05:00:00
# date_t3:  2016-09-14 06:00:00
#
# processing:  2016-09-14 06:00:00
# date_t1:  2016-09-14 07:00:00
# date_t2:  2016-09-14 08:00:00
# date_t3:  2016-09-14 09:00:00
#
# processing:  2016-09-14 09:00:00
# date_t1:  2016-09-14 10:00:00
# date_t2:  2016-09-14 11:00:00
# date_t3:  2016-09-14 12:00:00
#
# processing:  2016-09-14 12:00:00
# date_t1:  2016-09-14 13:00:00
# date_t2:  2016-09-14 14:00:00
# date_t3:  2016-09-14 15:00:00
#
# processing:  2016-09-14 15:00:00
# date_t1:  2016-09-14 16:00:00
# date_t2:  2016-09-14 17:00:00
# date_t3:  2016-09-14 18:00:00
#
# processing:  2016-09-14 18:00:00
# date_t1:  2016-09-14 19:00:00
# date_t2:  2016-09-14 20:00:00
# date_t3:  2016-09-14 21:00:00
#
# processing:  2016-09-14 21:00:00
# date_t1:  2016-09-14 22:00:00
# date_t2:  2016-09-14 23:00:00
# date_t3:  2016-09-15 00:00:00
#
# processing:  2016-09-15 00:00:00
# date_t1:  2016-09-15 01:00:00
# date_t2:  2016-09-15 02:00:00
# date_t3:  2016-09-15 03:00:00
#
# processing:  2016-09-15 03:00:00
# date_t1:  2016-09-15 04:00:00
# date_t2:  2016-09-15 05:00:00
# date_t3:  2016-09-15 06:00:00
#
# processing:  2016-09-15 06:00:00
# date_t1:  2016-09-15 07:00:00
# date_t2:  2016-09-15 08:00:00
# date_t3:  2016-09-15 09:00:00
#
# processing:  2016-09-15 09:00:00
# date_t1:  2016-09-15 10:00:00
# date_t2:  2016-09-15 11:00:00
# date_t3:  2016-09-15 12:00:00
#
# processing:  2016-09-15 12:00:00
# date_t1:  2016-09-15 13:00:00
# date_t2:  2016-09-15 14:00:00
# date_t3:  2016-09-15 15:00:00
#
# processing:  2016-09-15 15:00:00
# date_t1:  2016-09-15 16:00:00
# date_t2:  2016-09-15 17:00:00
# date_t3:  2016-09-15 18:00:00
#
# processing:  2016-09-15 18:00:00
# date_t1:  2016-09-15 19:00:00
# date_t2:  2016-09-15 20:00:00
# date_t3:  2016-09-15 21:00:00
#
# processing:  2016-09-15 21:00:00
# date_t1:  2016-09-15 22:00:00
# date_t2:  2016-09-15 23:00:00
# date_t3:  2016-09-16 00:00:00
#
# processing:  2016-09-16 00:00:00
# date_t1:  2016-09-16 01:00:00
# date_t2:  2016-09-16 02:00:00
# date_t3:  2016-09-16 03:00:00
#
# processing:  2016-09-16 03:00:00
# date_t1:  2016-09-16 04:00:00
# date_t2:  2016-09-16 05:00:00
# date_t3:  2016-09-16 06:00:00
#
# processing:  2016-09-16 06:00:00
# date_t1:  2016-09-16 07:00:00
# date_t2:  2016-09-16 08:00:00
# date_t3:  2016-09-16 09:00:00
#
# processing:  2016-09-16 09:00:00
# date_t1:  2016-09-16 10:00:00
# date_t2:  2016-09-16 11:00:00
# date_t3:  2016-09-16 12:00:00
#
# processing:  2016-09-16 12:00:00
# date_t1:  2016-09-16 13:00:00
# date_t2:  2016-09-16 14:00:00
# date_t3:  2016-09-16 15:00:00
#
# processing:  2016-09-16 15:00:00
# date_t1:  2016-09-16 16:00:00
# date_t2:  2016-09-16 17:00:00
# date_t3:  2016-09-16 18:00:00
#
# processing:  2016-09-16 18:00:00
# date_t1:  2016-09-16 19:00:00
# date_t2:  2016-09-16 20:00:00
# date_t3:  2016-09-16 21:00:00
#
# processing:  2016-09-16 21:00:00
# date_t1:  2016-09-16 22:00:00
# date_t2:  2016-09-16 23:00:00
# date_t3:  2016-09-17 00:00:00
#
# processing:  2016-09-17 00:00:00
# date_t1:  2016-09-17 01:00:00
# date_t2:  2016-09-17 02:00:00
# date_t3:  2016-09-17 03:00:00
#
# processing:  2016-09-17 03:00:00
# date_t1:  2016-09-17 04:00:00
# date_t2:  2016-09-17 05:00:00
# date_t3:  2016-09-17 06:00:00
#
# processing:  2016-09-17 06:00:00
# date_t1:  2016-09-17 07:00:00
# date_t2:  2016-09-17 08:00:00
# date_t3:  2016-09-17 09:00:00
#
# processing:  2016-09-17 09:00:00
# date_t1:  2016-09-17 10:00:00
# date_t2:  2016-09-17 11:00:00
# date_t3:  2016-09-17 12:00:00
#
# processing:  2016-09-17 12:00:00
# date_t1:  2016-09-17 13:00:00
# date_t2:  2016-09-17 14:00:00
# date_t3:  2016-09-17 15:00:00
#
# processing:  2016-09-17 15:00:00
# date_t1:  2016-09-17 16:00:00
# date_t2:  2016-09-17 17:00:00
# date_t3:  2016-09-17 18:00:00
#
# processing:  2016-09-17 18:00:00
# date_t1:  2016-09-17 19:00:00
# date_t2:  2016-09-17 20:00:00
# date_t3:  2016-09-17 21:00:00
#
# processing:  2016-09-17 21:00:00
# date_t1:  2016-09-17 22:00:00
# date_t2:  2016-09-17 23:00:00
# date_t3:  2016-09-18 00:00:00
#
# processing:  2016-09-18 00:00:00
# date_t1:  2016-09-18 01:00:00
# date_t2:  2016-09-18 02:00:00
# date_t3:  2016-09-18 03:00:00
#
# processing:  2016-09-18 03:00:00
# date_t1:  2016-09-18 04:00:00
# date_t2:  2016-09-18 05:00:00
# date_t3:  2016-09-18 06:00:00
#
# processing:  2016-09-18 06:00:00
# date_t1:  2016-09-18 07:00:00
# date_t2:  2016-09-18 08:00:00
# date_t3:  2016-09-18 09:00:00
#
# processing:  2016-09-18 09:00:00
# date_t1:  2016-09-18 10:00:00
# date_t2:  2016-09-18 11:00:00
# date_t3:  2016-09-18 12:00:00
#
# processing:  2016-09-18 12:00:00
# date_t1:  2016-09-18 13:00:00
# date_t2:  2016-09-18 14:00:00
# date_t3:  2016-09-18 15:00:00
#
# processing:  2016-09-18 15:00:00
# date_t1:  2016-09-18 16:00:00
# date_t2:  2016-09-18 17:00:00
# date_t3:  2016-09-18 18:00:00
#
# processing:  2016-09-18 18:00:00
# date_t1:  2016-09-18 19:00:00
# date_t2:  2016-09-18 20:00:00
# date_t3:  2016-09-18 21:00:00
#
# processing:  2016-09-18 21:00:00
# date_t1:  2016-09-18 22:00:00
# date_t2:  2016-09-18 23:00:00
# date_t3:  2016-09-19 00:00:00
#
# processing:  2016-09-19 00:00:00
# date_t1:  2016-09-19 01:00:00
# date_t2:  2016-09-19 02:00:00
# date_t3:  2016-09-19 03:00:00
#
# processing:  2016-09-19 03:00:00
# date_t1:  2016-09-19 04:00:00
# date_t2:  2016-09-19 05:00:00
# date_t3:  2016-09-19 06:00:00
#
# processing:  2016-09-19 06:00:00
# date_t1:  2016-09-19 07:00:00
# date_t2:  2016-09-19 08:00:00
# date_t3:  2016-09-19 09:00:00
#
# processing:  2016-09-19 09:00:00
# date_t1:  2016-09-19 10:00:00
# date_t2:  2016-09-19 11:00:00
# date_t3:  2016-09-19 12:00:00
#
# processing:  2016-09-19 12:00:00
# date_t1:  2016-09-19 13:00:00
# date_t2:  2016-09-19 14:00:00
# date_t3:  2016-09-19 15:00:00
#
# processing:  2016-09-19 15:00:00
# date_t1:  2016-09-19 16:00:00
# date_t2:  2016-09-19 17:00:00
# date_t3:  2016-09-19 18:00:00
#
# processing:  2016-09-19 18:00:00
# date_t1:  2016-09-19 19:00:00
# date_t2:  2016-09-19 20:00:00
# date_t3:  2016-09-19 21:00:00
#
# processing:  2016-09-19 21:00:00
# date_t1:  2016-09-19 22:00:00
# date_t2:  2016-09-19 23:00:00
# date_t3:  2016-09-20 00:00:00
#
# processing:  2016-09-20 00:00:00
# date_t1:  2016-09-20 01:00:00
# date_t2:  2016-09-20 02:00:00
# date_t3:  2016-09-20 03:00:00
#
# processing:  2016-09-20 03:00:00
# date_t1:  2016-09-20 04:00:00
# date_t2:  2016-09-20 05:00:00
# date_t3:  2016-09-20 06:00:00
#
# processing:  2016-09-20 06:00:00
# date_t1:  2016-09-20 07:00:00
# date_t2:  2016-09-20 08:00:00
# date_t3:  2016-09-20 09:00:00
#
# processing:  2016-09-20 09:00:00
# date_t1:  2016-09-20 10:00:00
# date_t2:  2016-09-20 11:00:00
# date_t3:  2016-09-20 12:00:00
#
# processing:  2016-09-20 12:00:00
# date_t1:  2016-09-20 13:00:00
# date_t2:  2016-09-20 14:00:00
# date_t3:  2016-09-20 15:00:00
#
# processing:  2016-09-20 15:00:00
# date_t1:  2016-09-20 16:00:00
# date_t2:  2016-09-20 17:00:00
# date_t3:  2016-09-20 18:00:00
#
# processing:  2016-09-20 18:00:00
# date_t1:  2016-09-20 19:00:00
# date_t2:  2016-09-20 20:00:00
# date_t3:  2016-09-20 21:00:00
#
# processing:  2016-09-20 21:00:00
# date_t1:  2016-09-20 22:00:00
# date_t2:  2016-09-20 23:00:00
# date_t3:  2016-09-21 00:00:00
#
# processing:  2016-09-21 00:00:00
# date_t1:  2016-09-21 01:00:00
# date_t2:  2016-09-21 02:00:00
# date_t3:  2016-09-21 03:00:00
#
# processing:  2016-09-21 03:00:00
# date_t1:  2016-09-21 04:00:00
# date_t2:  2016-09-21 05:00:00
# date_t3:  2016-09-21 06:00:00
#
# processing:  2016-09-21 06:00:00
# date_t1:  2016-09-21 07:00:00
# date_t2:  2016-09-21 08:00:00
# date_t3:  2016-09-21 09:00:00
#
# processing:  2016-09-21 09:00:00
# date_t1:  2016-09-21 10:00:00
# date_t2:  2016-09-21 11:00:00
# date_t3:  2016-09-21 12:00:00
#
# processing:  2016-09-21 12:00:00
# date_t1:  2016-09-21 13:00:00
# date_t2:  2016-09-21 14:00:00
# date_t3:  2016-09-21 15:00:00
#
# processing:  2016-09-21 15:00:00
# date_t1:  2016-09-21 16:00:00
# date_t2:  2016-09-21 17:00:00
# date_t3:  2016-09-21 18:00:00
#
# processing:  2016-09-21 18:00:00
# date_t1:  2016-09-21 19:00:00
# date_t2:  2016-09-21 20:00:00
# date_t3:  2016-09-21 21:00:00
#
# processing:  2016-09-21 21:00:00
# date_t1:  2016-09-21 22:00:00
# date_t2:  2016-09-21 23:00:00
# date_t3:  2016-09-22 00:00:00
#
# processing:  2016-09-22 00:00:00
# date_t1:  2016-09-22 01:00:00
# date_t2:  2016-09-22 02:00:00
# date_t3:  2016-09-22 03:00:00
#
# processing:  2016-09-22 03:00:00
# date_t1:  2016-09-22 04:00:00
# date_t2:  2016-09-22 05:00:00
# date_t3:  2016-09-22 06:00:00
#
# processing:  2016-09-22 06:00:00
# date_t1:  2016-09-22 07:00:00
# date_t2:  2016-09-22 08:00:00
# date_t3:  2016-09-22 09:00:00
#
# processing:  2016-09-22 09:00:00
# date_t1:  2016-09-22 10:00:00
# date_t2:  2016-09-22 11:00:00
# date_t3:  2016-09-22 12:00:00
#
# processing:  2016-09-22 12:00:00
# date_t1:  2016-09-22 13:00:00
# date_t2:  2016-09-22 14:00:00
# date_t3:  2016-09-22 15:00:00
#
# processing:  2016-09-22 15:00:00
# date_t1:  2016-09-22 16:00:00
# date_t2:  2016-09-22 17:00:00
# date_t3:  2016-09-22 18:00:00
#
# processing:  2016-09-22 18:00:00
# date_t1:  2016-09-22 19:00:00
# date_t2:  2016-09-22 20:00:00
# date_t3:  2016-09-22 21:00:00
#
# processing:  2016-09-22 21:00:00
# date_t1:  2016-09-22 22:00:00
# date_t2:  2016-09-22 23:00:00
# date_t3:  2016-09-23 00:00:00
#
# processing:  2016-09-23 00:00:00
# date_t1:  2016-09-23 01:00:00
# date_t2:  2016-09-23 02:00:00
# date_t3:  2016-09-23 03:00:00
#
# processing:  2016-09-23 03:00:00
# date_t1:  2016-09-23 04:00:00
# date_t2:  2016-09-23 05:00:00
# date_t3:  2016-09-23 06:00:00
#
# processing:  2016-09-23 06:00:00
# date_t1:  2016-09-23 07:00:00
# date_t2:  2016-09-23 08:00:00
# date_t3:  2016-09-23 09:00:00
#
# processing:  2016-09-23 09:00:00
# date_t1:  2016-09-23 10:00:00
# date_t2:  2016-09-23 11:00:00
# date_t3:  2016-09-23 12:00:00
#
# processing:  2016-09-23 12:00:00
# date_t1:  2016-09-23 13:00:00
# date_t2:  2016-09-23 14:00:00
# date_t3:  2016-09-23 15:00:00
#
# processing:  2016-09-23 15:00:00
# date_t1:  2016-09-23 16:00:00
# date_t2:  2016-09-23 17:00:00
# date_t3:  2016-09-23 18:00:00
#
# processing:  2016-09-23 18:00:00
# date_t1:  2016-09-23 19:00:00
# date_t2:  2016-09-23 20:00:00
# date_t3:  2016-09-23 21:00:00
#
# processing:  2016-09-23 21:00:00
# date_t1:  2016-09-23 22:00:00
# date_t2:  2016-09-23 23:00:00
# date_t3:  2016-09-24 00:00:00
#
# processing:  2016-09-24 00:00:00
# date_t1:  2016-09-24 01:00:00
# date_t2:  2016-09-24 02:00:00
# date_t3:  2016-09-24 03:00:00
#
# processing:  2016-09-24 03:00:00
# date_t1:  2016-09-24 04:00:00
# date_t2:  2016-09-24 05:00:00
# date_t3:  2016-09-24 06:00:00
#
# processing:  2016-09-24 06:00:00
# date_t1:  2016-09-24 07:00:00
# date_t2:  2016-09-24 08:00:00
# date_t3:  2016-09-24 09:00:00
#
# processing:  2016-09-24 09:00:00
# date_t1:  2016-09-24 10:00:00
# date_t2:  2016-09-24 11:00:00
# date_t3:  2016-09-24 12:00:00
#
# processing:  2016-09-24 12:00:00
# date_t1:  2016-09-24 13:00:00
# date_t2:  2016-09-24 14:00:00
# date_t3:  2016-09-24 15:00:00
#
# processing:  2016-09-24 15:00:00
# date_t1:  2016-09-24 16:00:00
# date_t2:  2016-09-24 17:00:00
# date_t3:  2016-09-24 18:00:00
#
# processing:  2016-09-24 18:00:00
# date_t1:  2016-09-24 19:00:00
# date_t2:  2016-09-24 20:00:00
# date_t3:  2016-09-24 21:00:00
#
# processing:  2016-09-24 21:00:00
# date_t1:  2016-09-24 22:00:00
# date_t2:  2016-09-24 23:00:00
# date_t3:  2016-09-25 00:00:00
#
# processing:  2016-09-25 00:00:00
# date_t1:  2016-09-25 01:00:00
# date_t2:  2016-09-25 02:00:00
# date_t3:  2016-09-25 03:00:00
#
# processing:  2016-09-25 03:00:00
# date_t1:  2016-09-25 04:00:00
# date_t2:  2016-09-25 05:00:00
# date_t3:  2016-09-25 06:00:00
#
# processing:  2016-09-25 06:00:00
# date_t1:  2016-09-25 07:00:00
# date_t2:  2016-09-25 08:00:00
# date_t3:  2016-09-25 09:00:00
#
# processing:  2016-09-25 09:00:00
# date_t1:  2016-09-25 10:00:00
# date_t2:  2016-09-25 11:00:00
# date_t3:  2016-09-25 12:00:00
#
# processing:  2016-09-25 12:00:00
# date_t1:  2016-09-25 13:00:00
# date_t2:  2016-09-25 14:00:00
# date_t3:  2016-09-25 15:00:00
#
# processing:  2016-09-25 15:00:00
# date_t1:  2016-09-25 16:00:00
# date_t2:  2016-09-25 17:00:00
# date_t3:  2016-09-25 18:00:00
#
# processing:  2016-09-25 18:00:00
# date_t1:  2016-09-25 19:00:00
# date_t2:  2016-09-25 20:00:00
# date_t3:  2016-09-25 21:00:00
#
# processing:  2016-09-25 21:00:00
# date_t1:  2016-09-25 22:00:00
# date_t2:  2016-09-25 23:00:00
# date_t3:  2016-09-26 00:00:00
#
# processing:  2016-09-26 00:00:00
# date_t1:  2016-09-26 01:00:00
# date_t2:  2016-09-26 02:00:00
# date_t3:  2016-09-26 03:00:00
#
# processing:  2016-09-26 03:00:00
# date_t1:  2016-09-26 04:00:00
# date_t2:  2016-09-26 05:00:00
# date_t3:  2016-09-26 06:00:00
#
# processing:  2016-09-26 06:00:00
# date_t1:  2016-09-26 07:00:00
# date_t2:  2016-09-26 08:00:00
# date_t3:  2016-09-26 09:00:00
#
# processing:  2016-09-26 09:00:00
# date_t1:  2016-09-26 10:00:00
# date_t2:  2016-09-26 11:00:00
# date_t3:  2016-09-26 12:00:00
#
# processing:  2016-09-26 12:00:00
# date_t1:  2016-09-26 13:00:00
# date_t2:  2016-09-26 14:00:00
# date_t3:  2016-09-26 15:00:00
#
# processing:  2016-09-26 15:00:00
# date_t1:  2016-09-26 16:00:00
# date_t2:  2016-09-26 17:00:00
# date_t3:  2016-09-26 18:00:00
#
# processing:  2016-09-26 18:00:00
# date_t1:  2016-09-26 19:00:00
# date_t2:  2016-09-26 20:00:00
# date_t3:  2016-09-26 21:00:00
#
# processing:  2016-09-26 21:00:00
# date_t1:  2016-09-26 22:00:00
# date_t2:  2016-09-26 23:00:00
# date_t3:  2016-09-27 00:00:00
#
# processing:  2016-09-27 00:00:00
# date_t1:  2016-09-27 01:00:00
# date_t2:  2016-09-27 02:00:00
# date_t3:  2016-09-27 03:00:00
#
# processing:  2016-09-27 03:00:00
# date_t1:  2016-09-27 04:00:00
# date_t2:  2016-09-27 05:00:00
# date_t3:  2016-09-27 06:00:00
#
# processing:  2016-09-27 06:00:00
# date_t1:  2016-09-27 07:00:00
# date_t2:  2016-09-27 08:00:00
# date_t3:  2016-09-27 09:00:00
#
# processing:  2016-09-27 09:00:00
# date_t1:  2016-09-27 10:00:00
# date_t2:  2016-09-27 11:00:00
# date_t3:  2016-09-27 12:00:00
#
# processing:  2016-09-27 12:00:00
# date_t1:  2016-09-27 13:00:00
# date_t2:  2016-09-27 14:00:00
# date_t3:  2016-09-27 15:00:00
#
# processing:  2016-09-27 15:00:00
# date_t1:  2016-09-27 16:00:00
# date_t2:  2016-09-27 17:00:00
# date_t3:  2016-09-27 18:00:00
#
# processing:  2016-09-27 18:00:00
# date_t1:  2016-09-27 19:00:00
# date_t2:  2016-09-27 20:00:00
# date_t3:  2016-09-27 21:00:00
#
# processing:  2016-09-27 21:00:00
# date_t1:  2016-09-27 22:00:00
# date_t2:  2016-09-27 23:00:00
# date_t3:  2016-09-28 00:00:00
#
# processing:  2016-09-28 00:00:00
# date_t1:  2016-09-28 01:00:00
# date_t2:  2016-09-28 02:00:00
# date_t3:  2016-09-28 03:00:00
#
# processing:  2016-09-28 03:00:00
# date_t1:  2016-09-28 04:00:00
# date_t2:  2016-09-28 05:00:00
# date_t3:  2016-09-28 06:00:00
#
# processing:  2016-09-28 06:00:00
# date_t1:  2016-09-28 07:00:00
# date_t2:  2016-09-28 08:00:00
# date_t3:  2016-09-28 09:00:00
#
# processing:  2016-09-28 09:00:00
# date_t1:  2016-09-28 10:00:00
# date_t2:  2016-09-28 11:00:00
# date_t3:  2016-09-28 12:00:00
#
# processing:  2016-09-28 12:00:00
# date_t1:  2016-09-28 13:00:00
# date_t2:  2016-09-28 14:00:00
# date_t3:  2016-09-28 15:00:00
#
# processing:  2016-09-28 15:00:00
# date_t1:  2016-09-28 16:00:00
# date_t2:  2016-09-28 17:00:00
# date_t3:  2016-09-28 18:00:00
#
# processing:  2016-09-28 18:00:00
# date_t1:  2016-09-28 19:00:00
# date_t2:  2016-09-28 20:00:00
# date_t3:  2016-09-28 21:00:00
#
# processing:  2016-09-28 21:00:00
# date_t1:  2016-09-28 22:00:00
# date_t2:  2016-09-28 23:00:00
# date_t3:  2016-09-29 00:00:00
#
# processing:  2016-09-29 00:00:00
# date_t1:  2016-09-29 01:00:00
# date_t2:  2016-09-29 02:00:00
# date_t3:  2016-09-29 03:00:00
#
# processing:  2016-09-29 03:00:00
# date_t1:  2016-09-29 04:00:00
# date_t2:  2016-09-29 05:00:00
# date_t3:  2016-09-29 06:00:00
#
# processing:  2016-09-29 06:00:00
# date_t1:  2016-09-29 07:00:00
# date_t2:  2016-09-29 08:00:00
# date_t3:  2016-09-29 09:00:00
#
# processing:  2016-09-29 09:00:00
# date_t1:  2016-09-29 10:00:00
# date_t2:  2016-09-29 11:00:00
# date_t3:  2016-09-29 12:00:00
#
# processing:  2016-09-29 12:00:00
# date_t1:  2016-09-29 13:00:00
# date_t2:  2016-09-29 14:00:00
# date_t3:  2016-09-29 15:00:00
#
# processing:  2016-09-29 15:00:00
# date_t1:  2016-09-29 16:00:00
# date_t2:  2016-09-29 17:00:00
# date_t3:  2016-09-29 18:00:00
#
# processing:  2016-09-29 18:00:00
# date_t1:  2016-09-29 19:00:00
# date_t2:  2016-09-29 20:00:00
# date_t3:  2016-09-29 21:00:00
#
# processing:  2016-09-29 21:00:00
# date_t1:  2016-09-29 22:00:00
# date_t2:  2016-09-29 23:00:00
# date_t3:  2016-09-30 00:00:00
#
# processing:  2016-09-30 00:00:00
# date_t1:  2016-09-30 01:00:00
# date_t2:  2016-09-30 02:00:00
# date_t3:  2016-09-30 03:00:00
#
# processing:  2016-09-30 03:00:00
# date_t1:  2016-09-30 04:00:00
# date_t2:  2016-09-30 05:00:00
# date_t3:  2016-09-30 06:00:00
#
# processing:  2016-09-30 06:00:00
# date_t1:  2016-09-30 07:00:00
# date_t2:  2016-09-30 08:00:00
# date_t3:  2016-09-30 09:00:00
#
# processing:  2016-09-30 09:00:00
# date_t1:  2016-09-30 10:00:00
# date_t2:  2016-09-30 11:00:00
# date_t3:  2016-09-30 12:00:00
#
# processing:  2016-09-30 12:00:00
# date_t1:  2016-09-30 13:00:00
# date_t2:  2016-09-30 14:00:00
# date_t3:  2016-09-30 15:00:00
#
# processing:  2016-09-30 15:00:00
# date_t1:  2016-09-30 16:00:00
# date_t2:  2016-09-30 17:00:00
# date_t3:  2016-09-30 18:00:00
#
# processing:  2016-09-30 18:00:00
# date_t1:  2016-09-30 19:00:00
# date_t2:  2016-09-30 20:00:00
# date_t3:  2016-09-30 21:00:00
#
# processing:  2016-09-30 21:00:00
# date_t1:  2016-09-30 22:00:00
# date_t2:  2016-09-30 23:00:00
# date_t3:  2016-10-01 00:00:00
#
# processing:  2016-10-01 00:00:00
# date_t1:  2016-10-01 01:00:00
# date_t2:  2016-10-01 02:00:00
# date_t3:  2016-10-01 03:00:00
#
# processing:  2016-10-01 03:00:00
# date_t1:  2016-10-01 04:00:00
# date_t2:  2016-10-01 05:00:00
# date_t3:  2016-10-01 06:00:00
#
# processing:  2016-10-01 06:00:00
# date_t1:  2016-10-01 07:00:00
# date_t2:  2016-10-01 08:00:00
# date_t3:  2016-10-01 09:00:00
#
# processing:  2016-10-01 09:00:00
# date_t1:  2016-10-01 10:00:00
# date_t2:  2016-10-01 11:00:00
# date_t3:  2016-10-01 12:00:00
#
# processing:  2016-10-01 12:00:00
# date_t1:  2016-10-01 13:00:00
# date_t2:  2016-10-01 14:00:00
# date_t3:  2016-10-01 15:00:00
#
# processing:  2016-10-01 15:00:00
# date_t1:  2016-10-01 16:00:00
# date_t2:  2016-10-01 17:00:00
# date_t3:  2016-10-01 18:00:00
#
# processing:  2016-10-01 18:00:00
# date_t1:  2016-10-01 19:00:00
# date_t2:  2016-10-01 20:00:00
# date_t3:  2016-10-01 21:00:00
#
# processing:  2016-10-01 21:00:00
# date_t1:  2016-10-01 22:00:00
# date_t2:  2016-10-01 23:00:00
# date_t3:  2016-10-02 00:00:00
#
# processing:  2016-10-02 00:00:00
# date_t1:  2016-10-02 01:00:00
# date_t2:  2016-10-02 02:00:00
# date_t3:  2016-10-02 03:00:00
#
# processing:  2016-10-02 03:00:00
# date_t1:  2016-10-02 04:00:00
# date_t2:  2016-10-02 05:00:00
# date_t3:  2016-10-02 06:00:00
#
# processing:  2016-10-02 06:00:00
# date_t1:  2016-10-02 07:00:00
# date_t2:  2016-10-02 08:00:00
# date_t3:  2016-10-02 09:00:00
#
# processing:  2016-10-02 09:00:00
# date_t1:  2016-10-02 10:00:00
# date_t2:  2016-10-02 11:00:00
# date_t3:  2016-10-02 12:00:00
#
# processing:  2016-10-02 12:00:00
# date_t1:  2016-10-02 13:00:00
# date_t2:  2016-10-02 14:00:00
# date_t3:  2016-10-02 15:00:00
#
# processing:  2016-10-02 15:00:00
# date_t1:  2016-10-02 16:00:00
# date_t2:  2016-10-02 17:00:00
# date_t3:  2016-10-02 18:00:00
#
# processing:  2016-10-02 18:00:00
# date_t1:  2016-10-02 19:00:00
# date_t2:  2016-10-02 20:00:00
# date_t3:  2016-10-02 21:00:00
#
# processing:  2016-10-02 21:00:00
# date_t1:  2016-10-02 22:00:00
# date_t2:  2016-10-02 23:00:00
# date_t3:  2016-10-03 00:00:00
#
# processing:  2016-10-03 00:00:00
# date_t1:  2016-10-03 01:00:00
# date_t2:  2016-10-03 02:00:00
# date_t3:  2016-10-03 03:00:00
#
# processing:  2016-10-03 03:00:00
# date_t1:  2016-10-03 04:00:00
# date_t2:  2016-10-03 05:00:00
# date_t3:  2016-10-03 06:00:00
#
# processing:  2016-10-03 06:00:00
# date_t1:  2016-10-03 07:00:00
# date_t2:  2016-10-03 08:00:00
# date_t3:  2016-10-03 09:00:00
#
# processing:  2016-10-03 09:00:00
# date_t1:  2016-10-03 10:00:00
# date_t2:  2016-10-03 11:00:00
# date_t3:  2016-10-03 12:00:00
#
# processing:  2016-10-03 12:00:00
# date_t1:  2016-10-03 13:00:00
# date_t2:  2016-10-03 14:00:00
# date_t3:  2016-10-03 15:00:00
#
# processing:  2016-10-03 15:00:00
# date_t1:  2016-10-03 16:00:00
# date_t2:  2016-10-03 17:00:00
# date_t3:  2016-10-03 18:00:00
#
# processing:  2016-10-03 18:00:00
# date_t1:  2016-10-03 19:00:00
# date_t2:  2016-10-03 20:00:00
# date_t3:  2016-10-03 21:00:00
#
# processing:  2016-10-03 21:00:00
# date_t1:  2016-10-03 22:00:00
# date_t2:  2016-10-03 23:00:00
# date_t3:  2016-10-04 00:00:00
#
# processing:  2016-10-04 00:00:00
# date_t1:  2016-10-04 01:00:00
# date_t2:  2016-10-04 02:00:00
# date_t3:  2016-10-04 03:00:00
#
# processing:  2016-10-04 03:00:00
# date_t1:  2016-10-04 04:00:00
# date_t2:  2016-10-04 05:00:00
# date_t3:  2016-10-04 06:00:00
#
# processing:  2016-10-04 06:00:00
# date_t1:  2016-10-04 07:00:00
# date_t2:  2016-10-04 08:00:00
# date_t3:  2016-10-04 09:00:00
#
# processing:  2016-10-04 09:00:00
# date_t1:  2016-10-04 10:00:00
# date_t2:  2016-10-04 11:00:00
# date_t3:  2016-10-04 12:00:00
#
# processing:  2016-10-04 12:00:00
# date_t1:  2016-10-04 13:00:00
# date_t2:  2016-10-04 14:00:00
# date_t3:  2016-10-04 15:00:00
#
# processing:  2016-10-04 15:00:00
# date_t1:  2016-10-04 16:00:00
# date_t2:  2016-10-04 17:00:00
# date_t3:  2016-10-04 18:00:00
#
# processing:  2016-10-04 18:00:00
# date_t1:  2016-10-04 19:00:00
# date_t2:  2016-10-04 20:00:00
# date_t3:  2016-10-04 21:00:00
#
# processing:  2016-10-04 21:00:00
# date_t1:  2016-10-04 22:00:00
# date_t2:  2016-10-04 23:00:00
# date_t3:  2016-10-05 00:00:00
#
# processing:  2016-10-05 00:00:00
# date_t1:  2016-10-05 01:00:00
# date_t2:  2016-10-05 02:00:00
# date_t3:  2016-10-05 03:00:00
#
# processing:  2016-10-05 03:00:00
# date_t1:  2016-10-05 04:00:00
# date_t2:  2016-10-05 05:00:00
# date_t3:  2016-10-05 06:00:00
#
# processing:  2016-10-05 06:00:00
# date_t1:  2016-10-05 07:00:00
# date_t2:  2016-10-05 08:00:00
# date_t3:  2016-10-05 09:00:00
#
# processing:  2016-10-05 09:00:00
# date_t1:  2016-10-05 10:00:00
# date_t2:  2016-10-05 11:00:00
# date_t3:  2016-10-05 12:00:00
#
# processing:  2016-10-05 12:00:00
# date_t1:  2016-10-05 13:00:00
# date_t2:  2016-10-05 14:00:00
# date_t3:  2016-10-05 15:00:00
#
# processing:  2016-10-05 15:00:00
# date_t1:  2016-10-05 16:00:00
# date_t2:  2016-10-05 17:00:00
# date_t3:  2016-10-05 18:00:00
#
# processing:  2016-10-05 18:00:00
# date_t1:  2016-10-05 19:00:00
# date_t2:  2016-10-05 20:00:00
# date_t3:  2016-10-05 21:00:00
#
# processing:  2016-10-05 21:00:00
# date_t1:  2016-10-05 22:00:00
# date_t2:  2016-10-05 23:00:00
# date_t3:  2016-10-06 00:00:00
#
# processing:  2016-10-06 00:00:00
# date_t1:  2016-10-06 01:00:00
# date_t2:  2016-10-06 02:00:00
# date_t3:  2016-10-06 03:00:00
#
# processing:  2016-10-06 03:00:00
# date_t1:  2016-10-06 04:00:00
# date_t2:  2016-10-06 05:00:00
# date_t3:  2016-10-06 06:00:00
#
# processing:  2016-10-06 06:00:00
# date_t1:  2016-10-06 07:00:00
# date_t2:  2016-10-06 08:00:00
# date_t3:  2016-10-06 09:00:00
#
# processing:  2016-10-06 09:00:00
# date_t1:  2016-10-06 10:00:00
# date_t2:  2016-10-06 11:00:00
# date_t3:  2016-10-06 12:00:00
#
# processing:  2016-10-06 12:00:00
# date_t1:  2016-10-06 13:00:00
# date_t2:  2016-10-06 14:00:00
# date_t3:  2016-10-06 15:00:00
#
# processing:  2016-10-06 15:00:00
# date_t1:  2016-10-06 16:00:00
# date_t2:  2016-10-06 17:00:00
# date_t3:  2016-10-06 18:00:00
#
# processing:  2016-10-06 18:00:00
# date_t1:  2016-10-06 19:00:00
# date_t2:  2016-10-06 20:00:00
# date_t3:  2016-10-06 21:00:00
#
# processing:  2016-10-06 21:00:00
# date_t1:  2016-10-06 22:00:00
# date_t2:  2016-10-06 23:00:00
# date_t3:  2016-10-07 00:00:00
#
# processing:  2016-10-07 00:00:00
# date_t1:  2016-10-07 01:00:00
# date_t2:  2016-10-07 02:00:00
# date_t3:  2016-10-07 03:00:00
#
# processing:  2016-10-07 03:00:00
# date_t1:  2016-10-07 04:00:00
# date_t2:  2016-10-07 05:00:00
# date_t3:  2016-10-07 06:00:00
#
# processing:  2016-10-07 06:00:00
# date_t1:  2016-10-07 07:00:00
# date_t2:  2016-10-07 08:00:00
# date_t3:  2016-10-07 09:00:00
#
# processing:  2016-10-07 09:00:00
# date_t1:  2016-10-07 10:00:00
# date_t2:  2016-10-07 11:00:00
# date_t3:  2016-10-07 12:00:00
#
# processing:  2016-10-07 12:00:00
# date_t1:  2016-10-07 13:00:00
# date_t2:  2016-10-07 14:00:00
# date_t3:  2016-10-07 15:00:00
#
# processing:  2016-10-07 15:00:00
# date_t1:  2016-10-07 16:00:00
# date_t2:  2016-10-07 17:00:00
# date_t3:  2016-10-07 18:00:00
#
# processing:  2016-10-07 18:00:00
# date_t1:  2016-10-07 19:00:00
# date_t2:  2016-10-07 20:00:00
# date_t3:  2016-10-07 21:00:00
#
# processing:  2016-10-07 21:00:00
# date_t1:  2016-10-07 22:00:00
# date_t2:  2016-10-07 23:00:00
# date_t3:  2016-10-08 00:00:00
#
# processing:  2016-10-08 00:00:00
# date_t1:  2016-10-08 01:00:00
# date_t2:  2016-10-08 02:00:00
# date_t3:  2016-10-08 03:00:00
#
# processing:  2016-10-08 03:00:00
# date_t1:  2016-10-08 04:00:00
# date_t2:  2016-10-08 05:00:00
# date_t3:  2016-10-08 06:00:00
#
# processing:  2016-10-08 06:00:00
# date_t1:  2016-10-08 07:00:00
# date_t2:  2016-10-08 08:00:00
# date_t3:  2016-10-08 09:00:00
#
# processing:  2016-10-08 09:00:00
# date_t1:  2016-10-08 10:00:00
# date_t2:  2016-10-08 11:00:00
# date_t3:  2016-10-08 12:00:00
#
# processing:  2016-10-08 12:00:00
# date_t1:  2016-10-08 13:00:00
# date_t2:  2016-10-08 14:00:00
# date_t3:  2016-10-08 15:00:00
#
# processing:  2016-10-08 15:00:00
# date_t1:  2016-10-08 16:00:00
# date_t2:  2016-10-08 17:00:00
# date_t3:  2016-10-08 18:00:00
#
# processing:  2016-10-08 18:00:00
# date_t1:  2016-10-08 19:00:00
# date_t2:  2016-10-08 20:00:00
# date_t3:  2016-10-08 21:00:00
#
# processing:  2016-10-08 21:00:00
# date_t1:  2016-10-08 22:00:00
# date_t2:  2016-10-08 23:00:00
# date_t3:  2016-10-09 00:00:00
#
# processing:  2016-10-09 00:00:00
# date_t1:  2016-10-09 01:00:00
# date_t2:  2016-10-09 02:00:00
# date_t3:  2016-10-09 03:00:00
#
# processing:  2016-10-09 03:00:00
# date_t1:  2016-10-09 04:00:00
# date_t2:  2016-10-09 05:00:00
# date_t3:  2016-10-09 06:00:00
#
# processing:  2016-10-09 06:00:00
# date_t1:  2016-10-09 07:00:00
# date_t2:  2016-10-09 08:00:00
# date_t3:  2016-10-09 09:00:00
#
# processing:  2016-10-09 09:00:00
# date_t1:  2016-10-09 10:00:00
# date_t2:  2016-10-09 11:00:00
# date_t3:  2016-10-09 12:00:00
#
# processing:  2016-10-09 12:00:00
# date_t1:  2016-10-09 13:00:00
# date_t2:  2016-10-09 14:00:00
# date_t3:  2016-10-09 15:00:00
#
# processing:  2016-10-09 15:00:00
# date_t1:  2016-10-09 16:00:00
# date_t2:  2016-10-09 17:00:00
# date_t3:  2016-10-09 18:00:00
#
# processing:  2016-10-09 18:00:00
# date_t1:  2016-10-09 19:00:00
# date_t2:  2016-10-09 20:00:00
# date_t3:  2016-10-09 21:00:00
#
# processing:  2016-10-09 21:00:00
# date_t1:  2016-10-09 22:00:00
# date_t2:  2016-10-09 23:00:00
# date_t3:  2016-10-10 00:00:00
#
# processing:  2016-10-10 00:00:00
# date_t1:  2016-10-10 01:00:00
# date_t2:  2016-10-10 02:00:00
# date_t3:  2016-10-10 03:00:00
#
# processing:  2016-10-10 03:00:00
# date_t1:  2016-10-10 04:00:00
# date_t2:  2016-10-10 05:00:00
# date_t3:  2016-10-10 06:00:00
#
# processing:  2016-10-10 06:00:00
# date_t1:  2016-10-10 07:00:00
# date_t2:  2016-10-10 08:00:00
# date_t3:  2016-10-10 09:00:00
#
# processing:  2016-10-10 09:00:00
# date_t1:  2016-10-10 10:00:00
# date_t2:  2016-10-10 11:00:00
# date_t3:  2016-10-10 12:00:00
#
# processing:  2016-10-10 12:00:00
# date_t1:  2016-10-10 13:00:00
# date_t2:  2016-10-10 14:00:00
# date_t3:  2016-10-10 15:00:00
#
# processing:  2016-10-10 15:00:00
# date_t1:  2016-10-10 16:00:00
# date_t2:  2016-10-10 17:00:00
# date_t3:  2016-10-10 18:00:00
#
# processing:  2016-10-10 18:00:00
# date_t1:  2016-10-10 19:00:00
# date_t2:  2016-10-10 20:00:00
# date_t3:  2016-10-10 21:00:00
#
# processing:  2016-10-10 21:00:00
# date_t1:  2016-10-10 22:00:00
# date_t2:  2016-10-10 23:00:00
# date_t3:  2016-10-11 00:00:00
#
# processing:  2016-10-11 00:00:00
# date_t1:  2016-10-11 01:00:00
# date_t2:  2016-10-11 02:00:00
# date_t3:  2016-10-11 03:00:00
#
# processing:  2016-10-11 03:00:00
# date_t1:  2016-10-11 04:00:00
# date_t2:  2016-10-11 05:00:00
# date_t3:  2016-10-11 06:00:00
#
# processing:  2016-10-11 06:00:00
# date_t1:  2016-10-11 07:00:00
# date_t2:  2016-10-11 08:00:00
# date_t3:  2016-10-11 09:00:00
#
# processing:  2016-10-11 09:00:00
# date_t1:  2016-10-11 10:00:00
# date_t2:  2016-10-11 11:00:00
# date_t3:  2016-10-11 12:00:00
#
# processing:  2016-10-11 12:00:00
# date_t1:  2016-10-11 13:00:00
# date_t2:  2016-10-11 14:00:00
# date_t3:  2016-10-11 15:00:00
#
# processing:  2016-10-11 15:00:00
# date_t1:  2016-10-11 16:00:00
# date_t2:  2016-10-11 17:00:00
# date_t3:  2016-10-11 18:00:00
#
# processing:  2016-10-11 18:00:00
# date_t1:  2016-10-11 19:00:00
# date_t2:  2016-10-11 20:00:00
# date_t3:  2016-10-11 21:00:00
#
# processing:  2016-10-11 21:00:00
# date_t1:  2016-10-11 22:00:00
# date_t2:  2016-10-11 23:00:00
# date_t3:  2016-10-12 00:00:00
#
# processing:  2016-10-12 00:00:00
# date_t1:  2016-10-12 01:00:00
# date_t2:  2016-10-12 02:00:00
# date_t3:  2016-10-12 03:00:00
#
# processing:  2016-10-12 03:00:00
# date_t1:  2016-10-12 04:00:00
# date_t2:  2016-10-12 05:00:00
# date_t3:  2016-10-12 06:00:00
#
# processing:  2016-10-12 06:00:00
# date_t1:  2016-10-12 07:00:00
# date_t2:  2016-10-12 08:00:00
# date_t3:  2016-10-12 09:00:00
#
# processing:  2016-10-12 09:00:00
# date_t1:  2016-10-12 10:00:00
# date_t2:  2016-10-12 11:00:00
# date_t3:  2016-10-12 12:00:00
#
# processing:  2016-10-12 12:00:00
# date_t1:  2016-10-12 13:00:00
# date_t2:  2016-10-12 14:00:00
# date_t3:  2016-10-12 15:00:00
#
# processing:  2016-10-12 15:00:00
# date_t1:  2016-10-12 16:00:00
# date_t2:  2016-10-12 17:00:00
# date_t3:  2016-10-12 18:00:00
#
# processing:  2016-10-12 18:00:00
# date_t1:  2016-10-12 19:00:00
# date_t2:  2016-10-12 20:00:00
# date_t3:  2016-10-12 21:00:00
#
# processing:  2016-10-12 21:00:00
# date_t1:  2016-10-12 22:00:00
# date_t2:  2016-10-12 23:00:00
# date_t3:  2016-10-13 00:00:00
#
# processing:  2016-10-13 00:00:00
# date_t1:  2016-10-13 01:00:00
# date_t2:  2016-10-13 02:00:00
# date_t3:  2016-10-13 03:00:00
#
# processing:  2016-10-13 03:00:00
# date_t1:  2016-10-13 04:00:00
# date_t2:  2016-10-13 05:00:00
# date_t3:  2016-10-13 06:00:00
#
# processing:  2016-10-13 06:00:00
# date_t1:  2016-10-13 07:00:00
# date_t2:  2016-10-13 08:00:00
# date_t3:  2016-10-13 09:00:00
#
# processing:  2016-10-13 09:00:00
# date_t1:  2016-10-13 10:00:00
# date_t2:  2016-10-13 11:00:00
# date_t3:  2016-10-13 12:00:00
#
# processing:  2016-10-13 12:00:00
# date_t1:  2016-10-13 13:00:00
# date_t2:  2016-10-13 14:00:00
# date_t3:  2016-10-13 15:00:00
#
# processing:  2016-10-13 15:00:00
# date_t1:  2016-10-13 16:00:00
# date_t2:  2016-10-13 17:00:00
# date_t3:  2016-10-13 18:00:00
#
# processing:  2016-10-13 18:00:00
# date_t1:  2016-10-13 19:00:00
# date_t2:  2016-10-13 20:00:00
# date_t3:  2016-10-13 21:00:00
#
# processing:  2016-10-13 21:00:00
# date_t1:  2016-10-13 22:00:00
# date_t2:  2016-10-13 23:00:00
# date_t3:  2016-10-14 00:00:00
#
# processing:  2016-10-14 00:00:00
# date_t1:  2016-10-14 01:00:00
# date_t2:  2016-10-14 02:00:00
# date_t3:  2016-10-14 03:00:00
#
# processing:  2016-10-14 03:00:00
# date_t1:  2016-10-14 04:00:00
# date_t2:  2016-10-14 05:00:00
# date_t3:  2016-10-14 06:00:00
#
# processing:  2016-10-14 06:00:00
# date_t1:  2016-10-14 07:00:00
# date_t2:  2016-10-14 08:00:00
# date_t3:  2016-10-14 09:00:00
#
# processing:  2016-10-14 09:00:00
# date_t1:  2016-10-14 10:00:00
# date_t2:  2016-10-14 11:00:00
# date_t3:  2016-10-14 12:00:00
#
# processing:  2016-10-14 12:00:00
# date_t1:  2016-10-14 13:00:00
# date_t2:  2016-10-14 14:00:00
# date_t3:  2016-10-14 15:00:00
#
# processing:  2016-10-14 15:00:00
# date_t1:  2016-10-14 16:00:00
# date_t2:  2016-10-14 17:00:00
# date_t3:  2016-10-14 18:00:00
#
# processing:  2016-10-14 18:00:00
# date_t1:  2016-10-14 19:00:00
# date_t2:  2016-10-14 20:00:00
# date_t3:  2016-10-14 21:00:00
#
# processing:  2016-10-14 21:00:00
# date_t1:  2016-10-14 22:00:00
# date_t2:  2016-10-14 23:00:00
# date_t3:  2016-10-15 00:00:00
#
# processing:  2016-10-15 00:00:00
# date_t1:  2016-10-15 01:00:00
# date_t2:  2016-10-15 02:00:00
# date_t3:  2016-10-15 03:00:00
#
# processing:  2016-10-15 03:00:00
# date_t1:  2016-10-15 04:00:00
# date_t2:  2016-10-15 05:00:00
# date_t3:  2016-10-15 06:00:00
#
# processing:  2016-10-15 06:00:00
# date_t1:  2016-10-15 07:00:00
# date_t2:  2016-10-15 08:00:00
# date_t3:  2016-10-15 09:00:00
#
# processing:  2016-10-15 09:00:00
# date_t1:  2016-10-15 10:00:00
# date_t2:  2016-10-15 11:00:00
# date_t3:  2016-10-15 12:00:00
#
# processing:  2016-10-15 12:00:00
# date_t1:  2016-10-15 13:00:00
# date_t2:  2016-10-15 14:00:00
# date_t3:  2016-10-15 15:00:00
#
# processing:  2016-10-15 15:00:00
# date_t1:  2016-10-15 16:00:00
# date_t2:  2016-10-15 17:00:00
# date_t3:  2016-10-15 18:00:00
#
# processing:  2016-10-15 18:00:00
# date_t1:  2016-10-15 19:00:00
# date_t2:  2016-10-15 20:00:00
# date_t3:  2016-10-15 21:00:00
#
# processing:  2016-10-15 21:00:00
# date_t1:  2016-10-15 22:00:00
# date_t2:  2016-10-15 23:00:00
# date_t3:  2016-10-16 00:00:00
#
# processing:  2016-10-16 00:00:00
# date_t1:  2016-10-16 01:00:00
# date_t2:  2016-10-16 02:00:00
# date_t3:  2016-10-16 03:00:00
#
# processing:  2016-10-16 03:00:00
# date_t1:  2016-10-16 04:00:00
# date_t2:  2016-10-16 05:00:00
# date_t3:  2016-10-16 06:00:00
#
# processing:  2016-10-16 06:00:00
# date_t1:  2016-10-16 07:00:00
# date_t2:  2016-10-16 08:00:00
# date_t3:  2016-10-16 09:00:00
#
# processing:  2016-10-16 09:00:00
# date_t1:  2016-10-16 10:00:00
# date_t2:  2016-10-16 11:00:00
# date_t3:  2016-10-16 12:00:00
#
# processing:  2016-10-16 12:00:00
# date_t1:  2016-10-16 13:00:00
# date_t2:  2016-10-16 14:00:00
# date_t3:  2016-10-16 15:00:00
#
# processing:  2016-10-16 15:00:00
# date_t1:  2016-10-16 16:00:00
# date_t2:  2016-10-16 17:00:00
# date_t3:  2016-10-16 18:00:00
#
# processing:  2016-10-16 18:00:00
# date_t1:  2016-10-16 19:00:00
# date_t2:  2016-10-16 20:00:00
# date_t3:  2016-10-16 21:00:00
#
# processing:  2016-10-16 21:00:00
# date_t1:  2016-10-16 22:00:00
# date_t2:  2016-10-16 23:00:00
# date_t3:  2016-10-17 00:00:00
#
# processing:  2016-10-17 00:00:00
# date_t1:  2016-10-17 01:00:00
# date_t2:  2016-10-17 02:00:00
# date_t3:  2016-10-17 03:00:00
#
# processing:  2016-10-17 03:00:00
# date_t1:  2016-10-17 04:00:00
# date_t2:  2016-10-17 05:00:00
# date_t3:  2016-10-17 06:00:00
#
# processing:  2016-10-17 06:00:00
# date_t1:  2016-10-17 07:00:00
# date_t2:  2016-10-17 08:00:00
# date_t3:  2016-10-17 09:00:00
#
# processing:  2016-10-17 09:00:00
# date_t1:  2016-10-17 10:00:00
# date_t2:  2016-10-17 11:00:00
# date_t3:  2016-10-17 12:00:00
#
# processing:  2016-10-17 12:00:00
# date_t1:  2016-10-17 13:00:00
# date_t2:  2016-10-17 14:00:00
# date_t3:  2016-10-17 15:00:00
#
# processing:  2016-10-17 15:00:00
# date_t1:  2016-10-17 16:00:00
# date_t2:  2016-10-17 17:00:00
# date_t3:  2016-10-17 18:00:00
#
# processing:  2016-10-17 18:00:00
# date_t1:  2016-10-17 19:00:00
# date_t2:  2016-10-17 20:00:00
# date_t3:  2016-10-17 21:00:00
#
# processing:  2016-10-17 21:00:00
# date_t1:  2016-10-17 22:00:00
# date_t2:  2016-10-17 23:00:00
# date_t3:  2016-10-18 00:00:00
#
# processing:  2016-10-18 00:00:00
# date_t1:  2016-10-18 01:00:00
# date_t2:  2016-10-18 02:00:00
# date_t3:  2016-10-18 03:00:00
#
# processing:  2016-10-18 03:00:00
# date_t1:  2016-10-18 04:00:00
# date_t2:  2016-10-18 05:00:00
# date_t3:  2016-10-18 06:00:00
#
# processing:  2016-10-18 06:00:00
# date_t1:  2016-10-18 07:00:00
# date_t2:  2016-10-18 08:00:00
# date_t3:  2016-10-18 09:00:00
#
# processing:  2016-10-18 09:00:00
# date_t1:  2016-10-18 10:00:00
# date_t2:  2016-10-18 11:00:00
# date_t3:  2016-10-18 12:00:00
#
# processing:  2016-10-18 12:00:00
# date_t1:  2016-10-18 13:00:00
# date_t2:  2016-10-18 14:00:00
# date_t3:  2016-10-18 15:00:00
#
# processing:  2016-10-18 15:00:00
# date_t1:  2016-10-18 16:00:00
# date_t2:  2016-10-18 17:00:00
# date_t3:  2016-10-18 18:00:00
#
# processing:  2016-10-18 18:00:00
# date_t1:  2016-10-18 19:00:00
# date_t2:  2016-10-18 20:00:00
# date_t3:  2016-10-18 21:00:00
#
# processing:  2016-10-18 21:00:00
# date_t1:  2016-10-18 22:00:00
# date_t2:  2016-10-18 23:00:00
# date_t3:  2016-10-19 00:00:00
#
# processing:  2016-10-19 00:00:00
# date_t1:  2016-10-19 01:00:00
# date_t2:  2016-10-19 02:00:00
# date_t3:  2016-10-19 03:00:00
#
# processing:  2016-10-19 03:00:00
# date_t1:  2016-10-19 04:00:00
# date_t2:  2016-10-19 05:00:00
# date_t3:  2016-10-19 06:00:00
#
# processing:  2016-10-19 06:00:00
# date_t1:  2016-10-19 07:00:00
# date_t2:  2016-10-19 08:00:00
# date_t3:  2016-10-19 09:00:00
#
# processing:  2016-10-19 09:00:00
# date_t1:  2016-10-19 10:00:00
# date_t2:  2016-10-19 11:00:00
# date_t3:  2016-10-19 12:00:00
#
# processing:  2016-10-19 12:00:00
# date_t1:  2016-10-19 13:00:00
# date_t2:  2016-10-19 14:00:00
# date_t3:  2016-10-19 15:00:00
#
# processing:  2016-10-19 15:00:00
# date_t1:  2016-10-19 16:00:00
# date_t2:  2016-10-19 17:00:00
# date_t3:  2016-10-19 18:00:00
#
# processing:  2016-10-19 18:00:00
# date_t1:  2016-10-19 19:00:00
# date_t2:  2016-10-19 20:00:00
# date_t3:  2016-10-19 21:00:00
#
# processing:  2016-10-19 21:00:00
# date_t1:  2016-10-19 22:00:00
# date_t2:  2016-10-19 23:00:00
# date_t3:  2016-10-20 00:00:00
#
# processing:  2016-10-20 00:00:00
# date_t1:  2016-10-20 01:00:00
# date_t2:  2016-10-20 02:00:00
# date_t3:  2016-10-20 03:00:00
#
# processing:  2016-10-20 03:00:00
# date_t1:  2016-10-20 04:00:00
# date_t2:  2016-10-20 05:00:00
# date_t3:  2016-10-20 06:00:00
#
# processing:  2016-10-20 06:00:00
# date_t1:  2016-10-20 07:00:00
# date_t2:  2016-10-20 08:00:00
# date_t3:  2016-10-20 09:00:00
#
# processing:  2016-10-20 09:00:00
# date_t1:  2016-10-20 10:00:00
# date_t2:  2016-10-20 11:00:00
# date_t3:  2016-10-20 12:00:00
#
# processing:  2016-10-20 12:00:00
# date_t1:  2016-10-20 13:00:00
# date_t2:  2016-10-20 14:00:00
# date_t3:  2016-10-20 15:00:00
#
# processing:  2016-10-20 15:00:00
# date_t1:  2016-10-20 16:00:00
# date_t2:  2016-10-20 17:00:00
# date_t3:  2016-10-20 18:00:00
#
# processing:  2016-10-20 18:00:00
# date_t1:  2016-10-20 19:00:00
# date_t2:  2016-10-20 20:00:00
# date_t3:  2016-10-20 21:00:00
#
# processing:  2016-10-20 21:00:00
# date_t1:  2016-10-20 22:00:00
# date_t2:  2016-10-20 23:00:00
# date_t3:  2016-10-21 00:00:00
#
# processing:  2016-10-21 00:00:00
# date_t1:  2016-10-21 01:00:00
# date_t2:  2016-10-21 02:00:00
# date_t3:  2016-10-21 03:00:00
#
# processing:  2016-10-21 03:00:00
# date_t1:  2016-10-21 04:00:00
# date_t2:  2016-10-21 05:00:00
# date_t3:  2016-10-21 06:00:00
#
# processing:  2016-10-21 06:00:00
# date_t1:  2016-10-21 07:00:00
# date_t2:  2016-10-21 08:00:00
# date_t3:  2016-10-21 09:00:00
#
# processing:  2016-10-21 09:00:00
# date_t1:  2016-10-21 10:00:00
# date_t2:  2016-10-21 11:00:00
# date_t3:  2016-10-21 12:00:00
#
# processing:  2016-10-21 12:00:00
# date_t1:  2016-10-21 13:00:00
# date_t2:  2016-10-21 14:00:00
# date_t3:  2016-10-21 15:00:00
#
# processing:  2016-10-21 15:00:00
# date_t1:  2016-10-21 16:00:00
# date_t2:  2016-10-21 17:00:00
# date_t3:  2016-10-21 18:00:00
#
# processing:  2016-10-21 18:00:00
# date_t1:  2016-10-21 19:00:00
# date_t2:  2016-10-21 20:00:00
# date_t3:  2016-10-21 21:00:00
#
# processing:  2016-10-21 21:00:00
# date_t1:  2016-10-21 22:00:00
# date_t2:  2016-10-21 23:00:00
# date_t3:  2016-10-22 00:00:00
#
# processing:  2016-10-22 00:00:00
# date_t1:  2016-10-22 01:00:00
# date_t2:  2016-10-22 02:00:00
# date_t3:  2016-10-22 03:00:00
#
# processing:  2016-10-22 03:00:00
# date_t1:  2016-10-22 04:00:00
# date_t2:  2016-10-22 05:00:00
# date_t3:  2016-10-22 06:00:00
#
# processing:  2016-10-22 06:00:00
# date_t1:  2016-10-22 07:00:00
# date_t2:  2016-10-22 08:00:00
# date_t3:  2016-10-22 09:00:00
#
# processing:  2016-10-22 09:00:00
# date_t1:  2016-10-22 10:00:00
# date_t2:  2016-10-22 11:00:00
# date_t3:  2016-10-22 12:00:00
#
# processing:  2016-10-22 12:00:00
# date_t1:  2016-10-22 13:00:00
# date_t2:  2016-10-22 14:00:00
# date_t3:  2016-10-22 15:00:00
#
# processing:  2016-10-22 15:00:00
# date_t1:  2016-10-22 16:00:00
# date_t2:  2016-10-22 17:00:00
# date_t3:  2016-10-22 18:00:00
#
# processing:  2016-10-22 18:00:00
# date_t1:  2016-10-22 19:00:00
# date_t2:  2016-10-22 20:00:00
# date_t3:  2016-10-22 21:00:00
#
# processing:  2016-10-22 21:00:00
# date_t1:  2016-10-22 22:00:00
# date_t2:  2016-10-22 23:00:00
# date_t3:  2016-10-23 00:00:00
#
# processing:  2016-10-23 00:00:00
# date_t1:  2016-10-23 01:00:00
# date_t2:  2016-10-23 02:00:00
# date_t3:  2016-10-23 03:00:00
#
# processing:  2016-10-23 03:00:00
# date_t1:  2016-10-23 04:00:00
# date_t2:  2016-10-23 05:00:00
# date_t3:  2016-10-23 06:00:00
#
# processing:  2016-10-23 06:00:00
# date_t1:  2016-10-23 07:00:00
# date_t2:  2016-10-23 08:00:00
# date_t3:  2016-10-23 09:00:00
#
# processing:  2016-10-23 09:00:00
# date_t1:  2016-10-23 10:00:00
# date_t2:  2016-10-23 11:00:00
# date_t3:  2016-10-23 12:00:00
#
# processing:  2016-10-23 12:00:00
# date_t1:  2016-10-23 13:00:00
# date_t2:  2016-10-23 14:00:00
# date_t3:  2016-10-23 15:00:00
#
# processing:  2016-10-23 15:00:00
# date_t1:  2016-10-23 16:00:00
# date_t2:  2016-10-23 17:00:00
# date_t3:  2016-10-23 18:00:00
#
# processing:  2016-10-23 18:00:00
# date_t1:  2016-10-23 19:00:00
# date_t2:  2016-10-23 20:00:00
# date_t3:  2016-10-23 21:00:00
#
# processing:  2016-10-23 21:00:00
# date_t1:  2016-10-23 22:00:00
# date_t2:  2016-10-23 23:00:00
# date_t3:  2016-10-24 00:00:00
#
# processing:  2016-10-24 00:00:00
# date_t1:  2016-10-24 01:00:00
# date_t2:  2016-10-24 02:00:00
# date_t3:  2016-10-24 03:00:00
#
# processing:  2016-10-24 03:00:00
# date_t1:  2016-10-24 04:00:00
# date_t2:  2016-10-24 05:00:00
# date_t3:  2016-10-24 06:00:00
#
# processing:  2016-10-24 06:00:00
# date_t1:  2016-10-24 07:00:00
# date_t2:  2016-10-24 08:00:00
# date_t3:  2016-10-24 09:00:00
#
# processing:  2016-10-24 09:00:00
# date_t1:  2016-10-24 10:00:00
# date_t2:  2016-10-24 11:00:00
# date_t3:  2016-10-24 12:00:00
#
# processing:  2016-10-24 12:00:00
# date_t1:  2016-10-24 13:00:00
# date_t2:  2016-10-24 14:00:00
# date_t3:  2016-10-24 15:00:00
#
# processing:  2016-10-24 15:00:00
# date_t1:  2016-10-24 16:00:00
# date_t2:  2016-10-24 17:00:00
# date_t3:  2016-10-24 18:00:00
#
# processing:  2016-10-24 18:00:00
# date_t1:  2016-10-24 19:00:00
# date_t2:  2016-10-24 20:00:00
# date_t3:  2016-10-24 21:00:00
#
# processing:  2016-10-24 21:00:00
# date_t1:  2016-10-24 22:00:00
# date_t2:  2016-10-24 23:00:00
# date_t3:  2016-10-25 00:00:00
#
# processing:  2016-10-25 00:00:00
# date_t1:  2016-10-25 01:00:00
# date_t2:  2016-10-25 02:00:00
# date_t3:  2016-10-25 03:00:00
#
# processing:  2016-10-25 03:00:00
# date_t1:  2016-10-25 04:00:00
# date_t2:  2016-10-25 05:00:00
# date_t3:  2016-10-25 06:00:00
#
# processing:  2016-10-25 06:00:00
# date_t1:  2016-10-25 07:00:00
# date_t2:  2016-10-25 08:00:00
# date_t3:  2016-10-25 09:00:00
#
# processing:  2016-10-25 09:00:00
# date_t1:  2016-10-25 10:00:00
# date_t2:  2016-10-25 11:00:00
# date_t3:  2016-10-25 12:00:00
#
# processing:  2016-10-25 12:00:00
# date_t1:  2016-10-25 13:00:00
# date_t2:  2016-10-25 14:00:00
# date_t3:  2016-10-25 15:00:00
#
# processing:  2016-10-25 15:00:00
# date_t1:  2016-10-25 16:00:00
# date_t2:  2016-10-25 17:00:00
# date_t3:  2016-10-25 18:00:00
#
# processing:  2016-10-25 18:00:00
# date_t1:  2016-10-25 19:00:00
# date_t2:  2016-10-25 20:00:00
# date_t3:  2016-10-25 21:00:00
#
# processing:  2016-10-25 21:00:00
# date_t1:  2016-10-25 22:00:00
# date_t2:  2016-10-25 23:00:00
# date_t3:  2016-10-26 00:00:00
#
# ...
#
# processing:  2016-12-06 21:00:00
# date_t1:  2016-12-06 22:00:00
# date_t2:  2016-12-06 23:00:00
# date_t3:  2016-12-07 00:00:00
#
# processing:  2016-12-07 00:00:00
# date_t1:  2016-12-07 01:00:00
# date_t2:  2016-12-07 02:00:00
# date_t3:  2016-12-07 03:00:00
#
# processing:  2016-12-07 03:00:00
# date_t1:  2016-12-07 04:00:00
# date_t2:  2016-12-07 05:00:00
# date_t3:  2016-12-07 06:00:00
#
# processing:  2016-12-07 06:00:00
# date_t1:  2016-12-07 07:00:00
# date_t2:  2016-12-07 08:00:00
# date_t3:  2016-12-07 09:00:00
#
# processing:  2016-12-07 09:00:00
# date_t1:  2016-12-07 10:00:00
# date_t2:  2016-12-07 11:00:00
# date_t3:  2016-12-07 12:00:00
#
# processing:  2016-12-07 12:00:00
# date_t1:  2016-12-07 13:00:00
# date_t2:  2016-12-07 14:00:00
# date_t3:  2016-12-07 15:00:00
#
# processing:  2016-12-07 15:00:00
# date_t1:  2016-12-07 16:00:00
# date_t2:  2016-12-07 17:00:00
# date_t3:  2016-12-07 18:00:00
#
# processing:  2016-12-07 18:00:00
# date_t1:  2016-12-07 19:00:00
# date_t2:  2016-12-07 20:00:00
# date_t3:  2016-12-07 21:00:00
#
# processing:  2016-12-07 21:00:00
# date_t1:  2016-12-07 22:00:00
# date_t2:  2016-12-07 23:00:00
# date_t3:  2016-12-08 00:00:00
#
# processing:  2016-12-08 00:00:00
# date_t1:  2016-12-08 01:00:00
# date_t2:  2016-12-08 02:00:00
# date_t3:  2016-12-08 03:00:00
#
# processing:  2016-12-08 03:00:00
# date_t1:  2016-12-08 04:00:00
# date_t2:  2016-12-08 05:00:00
# date_t3:  2016-12-08 06:00:00
#
# processing:  2016-12-08 06:00:00
# date_t1:  2016-12-08 07:00:00
# date_t2:  2016-12-08 08:00:00
# date_t3:  2016-12-08 09:00:00
#
# processing:  2016-12-08 09:00:00
# date_t1:  2016-12-08 10:00:00
# date_t2:  2016-12-08 11:00:00
# date_t3:  2016-12-08 12:00:00
#
# processing:  2016-12-08 12:00:00
# date_t1:  2016-12-08 13:00:00
# date_t2:  2016-12-08 14:00:00
# date_t3:  2016-12-08 15:00:00
#
# processing:  2016-12-08 15:00:00
# date_t1:  2016-12-08 16:00:00
# date_t2:  2016-12-08 17:00:00
# date_t3:  2016-12-08 18:00:00
#
# processing:  2016-12-08 18:00:00
# date_t1:  2016-12-08 19:00:00
# date_t2:  2016-12-08 20:00:00
# date_t3:  2016-12-08 21:00:00
#
# processing:  2016-12-08 21:00:00
# date_t1:  2016-12-08 22:00:00
# date_t2:  2016-12-08 23:00:00
# date_t3:  2016-12-09 00:00:00
#
# processing:  2016-12-09 00:00:00
# date_t1:  2016-12-09 01:00:00
# date_t2:  2016-12-09 02:00:00
# date_t3:  2016-12-09 03:00:00
#
# processing:  2016-12-09 03:00:00
# date_t1:  2016-12-09 04:00:00
# date_t2:  2016-12-09 05:00:00
# date_t3:  2016-12-09 06:00:00
#
# processing:  2016-12-09 06:00:00
# date_t1:  2016-12-09 07:00:00
# date_t2:  2016-12-09 08:00:00
# date_t3:  2016-12-09 09:00:00
#
# processing:  2016-12-09 09:00:00
# date_t1:  2016-12-09 10:00:00
# date_t2:  2016-12-09 11:00:00
# date_t3:  2016-12-09 12:00:00
#
# processing:  2016-12-09 12:00:00
# date_t1:  2016-12-09 13:00:00
# date_t2:  2016-12-09 14:00:00
# date_t3:  2016-12-09 15:00:00
#
# processing:  2016-12-09 15:00:00
# date_t1:  2016-12-09 16:00:00
# date_t2:  2016-12-09 17:00:00
# date_t3:  2016-12-09 18:00:00
#
# processing:  2016-12-09 18:00:00
# date_t1:  2016-12-09 19:00:00
# date_t2:  2016-12-09 20:00:00
# date_t3:  2016-12-09 21:00:00
#
# processing:  2016-12-09 21:00:00
# date_t1:  2016-12-09 22:00:00
# date_t2:  2016-12-09 23:00:00
# date_t3:  2016-12-10 00:00:00
#
# processing:  2016-12-10 00:00:00
# date_t1:  2016-12-10 01:00:00
# date_t2:  2016-12-10 02:00:00
# date_t3:  2016-12-10 03:00:00
#
# processing:  2016-12-10 03:00:00
# date_t1:  2016-12-10 04:00:00
# date_t2:  2016-12-10 05:00:00
# date_t3:  2016-12-10 06:00:00
#
# processing:  2016-12-10 06:00:00
# date_t1:  2016-12-10 07:00:00
# date_t2:  2016-12-10 08:00:00
# date_t3:  2016-12-10 09:00:00
#
# processing:  2016-12-10 09:00:00
# date_t1:  2016-12-10 10:00:00
# date_t2:  2016-12-10 11:00:00
# date_t3:  2016-12-10 12:00:00
#
# processing:  2016-12-10 12:00:00
# date_t1:  2016-12-10 13:00:00
# date_t2:  2016-12-10 14:00:00
# date_t3:  2016-12-10 15:00:00
#
# processing:  2016-12-10 15:00:00
# date_t1:  2016-12-10 16:00:00
# date_t2:  2016-12-10 17:00:00
# date_t3:  2016-12-10 18:00:00
#
# processing:  2016-12-10 18:00:00
# date_t1:  2016-12-10 19:00:00
# date_t2:  2016-12-10 20:00:00
# date_t3:  2016-12-10 21:00:00
#
# processing:  2016-12-10 21:00:00
# date_t1:  2016-12-10 22:00:00
# date_t2:  2016-12-10 23:00:00
# date_t3:  2016-12-11 00:00:00
#
# processing:  2016-12-11 00:00:00
# date_t1:  2016-12-11 01:00:00
# date_t2:  2016-12-11 02:00:00
# date_t3:  2016-12-11 03:00:00
#
# processing:  2016-12-11 03:00:00
# date_t1:  2016-12-11 04:00:00
# date_t2:  2016-12-11 05:00:00
# date_t3:  2016-12-11 06:00:00
#
# processing:  2016-12-11 06:00:00
# date_t1:  2016-12-11 07:00:00
# date_t2:  2016-12-11 08:00:00
# date_t3:  2016-12-11 09:00:00
#
# processing:  2016-12-11 09:00:00
# date_t1:  2016-12-11 10:00:00
# date_t2:  2016-12-11 11:00:00
# date_t3:  2016-12-11 12:00:00
#
# processing:  2016-12-11 12:00:00
# date_t1:  2016-12-11 13:00:00
# date_t2:  2016-12-11 14:00:00
# date_t3:  2016-12-11 15:00:00
#
# processing:  2016-12-11 15:00:00
# date_t1:  2016-12-11 16:00:00
# date_t2:  2016-12-11 17:00:00
# date_t3:  2016-12-11 18:00:00
#
# processing:  2016-12-11 18:00:00
# date_t1:  2016-12-11 19:00:00
# date_t2:  2016-12-11 20:00:00
# date_t3:  2016-12-11 21:00:00
#
# processing:  2016-12-11 21:00:00
# date_t1:  2016-12-11 22:00:00
# date_t2:  2016-12-11 23:00:00
# date_t3:  2016-12-12 00:00:00
#
# processing:  2016-12-12 00:00:00
# date_t1:  2016-12-12 01:00:00
# date_t2:  2016-12-12 02:00:00
# date_t3:  2016-12-12 03:00:00
#
# processing:  2016-12-12 03:00:00
# date_t1:  2016-12-12 04:00:00
# date_t2:  2016-12-12 05:00:00
# date_t3:  2016-12-12 06:00:00
#
# processing:  2016-12-12 06:00:00
# date_t1:  2016-12-12 07:00:00
# date_t2:  2016-12-12 08:00:00
# date_t3:  2016-12-12 09:00:00
#
# processing:  2016-12-12 09:00:00
# date_t1:  2016-12-12 10:00:00
# date_t2:  2016-12-12 11:00:00
# date_t3:  2016-12-12 12:00:00
#
# processing:  2016-12-12 12:00:00
# date_t1:  2016-12-12 13:00:00
# date_t2:  2016-12-12 14:00:00
# date_t3:  2016-12-12 15:00:00
#
# processing:  2016-12-12 15:00:00
# date_t1:  2016-12-12 16:00:00
# date_t2:  2016-12-12 17:00:00
# date_t3:  2016-12-12 18:00:00
#
# processing:  2016-12-12 18:00:00
# date_t1:  2016-12-12 19:00:00
# date_t2:  2016-12-12 20:00:00
# date_t3:  2016-12-12 21:00:00
#
# processing:  2016-12-12 21:00:00
# date_t1:  2016-12-12 22:00:00
# date_t2:  2016-12-12 23:00:00
# date_t3:  2016-12-13 00:00:00
#
# processing:  2016-12-13 00:00:00
# date_t1:  2016-12-13 01:00:00
# date_t2:  2016-12-13 02:00:00
# date_t3:  2016-12-13 03:00:00
#
# processing:  2016-12-13 03:00:00
# date_t1:  2016-12-13 04:00:00
# date_t2:  2016-12-13 05:00:00
# date_t3:  2016-12-13 06:00:00
#
# processing:  2016-12-13 06:00:00
# date_t1:  2016-12-13 07:00:00
# date_t2:  2016-12-13 08:00:00
# date_t3:  2016-12-13 09:00:00
#
# processing:  2016-12-13 09:00:00
# date_t1:  2016-12-13 10:00:00
# date_t2:  2016-12-13 11:00:00
# date_t3:  2016-12-13 12:00:00
#
# processing:  2016-12-13 12:00:00
# date_t1:  2016-12-13 13:00:00
# date_t2:  2016-12-13 14:00:00
# date_t3:  2016-12-13 15:00:00
#
# processing:  2016-12-13 15:00:00
# date_t1:  2016-12-13 16:00:00
# date_t2:  2016-12-13 17:00:00
# date_t3:  2016-12-13 18:00:00
#
# processing:  2016-12-13 18:00:00
# date_t1:  2016-12-13 19:00:00
# date_t2:  2016-12-13 20:00:00
# date_t3:  2016-12-13 21:00:00
#
# processing:  2016-12-13 21:00:00
# date_t1:  2016-12-13 22:00:00
# date_t2:  2016-12-13 23:00:00
# date_t3:  2016-12-14 00:00:00
#
# processing:  2016-12-14 00:00:00
# date_t1:  2016-12-14 01:00:00
# date_t2:  2016-12-14 02:00:00
# date_t3:  2016-12-14 03:00:00
#
# processing:  2016-12-14 03:00:00
# date_t1:  2016-12-14 04:00:00
# date_t2:  2016-12-14 05:00:00
# date_t3:  2016-12-14 06:00:00
#
# processing:  2016-12-14 06:00:00
# date_t1:  2016-12-14 07:00:00
# date_t2:  2016-12-14 08:00:00
# date_t3:  2016-12-14 09:00:00
#
# processing:  2016-12-14 09:00:00
# date_t1:  2016-12-14 10:00:00
# date_t2:  2016-12-14 11:00:00
# date_t3:  2016-12-14 12:00:00
#
# processing:  2016-12-14 12:00:00
# date_t1:  2016-12-14 13:00:00
# date_t2:  2016-12-14 14:00:00
# date_t3:  2016-12-14 15:00:00
#
# processing:  2016-12-14 15:00:00
# date_t1:  2016-12-14 16:00:00
# date_t2:  2016-12-14 17:00:00
# date_t3:  2016-12-14 18:00:00
#
# processing:  2016-12-14 18:00:00
# date_t1:  2016-12-14 19:00:00
# date_t2:  2016-12-14 20:00:00
# date_t3:  2016-12-14 21:00:00
#
# processing:  2016-12-14 21:00:00
# date_t1:  2016-12-14 22:00:00
# date_t2:  2016-12-14 23:00:00
# date_t3:  2016-12-15 00:00:00
#
# processing:  2016-12-15 00:00:00
# date_t1:  2016-12-15 01:00:00
# date_t2:  2016-12-15 02:00:00
# date_t3:  2016-12-15 03:00:00
#
# processing:  2016-12-15 03:00:00
# date_t1:  2016-12-15 04:00:00
# date_t2:  2016-12-15 05:00:00
# date_t3:  2016-12-15 06:00:00
#
# processing:  2016-12-15 06:00:00
# date_t1:  2016-12-15 07:00:00
# date_t2:  2016-12-15 08:00:00
# date_t3:  2016-12-15 09:00:00
#
# processing:  2016-12-15 09:00:00
# date_t1:  2016-12-15 10:00:00
# date_t2:  2016-12-15 11:00:00
# date_t3:  2016-12-15 12:00:00
#
# processing:  2016-12-15 12:00:00
# date_t1:  2016-12-15 13:00:00
# date_t2:  2016-12-15 14:00:00
# date_t3:  2016-12-15 15:00:00
#
# processing:  2016-12-15 15:00:00
# date_t1:  2016-12-15 16:00:00
# date_t2:  2016-12-15 17:00:00
# date_t3:  2016-12-15 18:00:00
#
# processing:  2016-12-15 18:00:00
# date_t1:  2016-12-15 19:00:00
# date_t2:  2016-12-15 20:00:00
# date_t3:  2016-12-15 21:00:00
#
# processing:  2016-12-15 21:00:00
# date_t1:  2016-12-15 22:00:00
# date_t2:  2016-12-15 23:00:00
# date_t3:  2016-12-16 00:00:00
#
# processing:  2016-12-16 00:00:00
# date_t1:  2016-12-16 01:00:00
# date_t2:  2016-12-16 02:00:00
# date_t3:  2016-12-16 03:00:00
#
# processing:  2016-12-16 03:00:00
# date_t1:  2016-12-16 04:00:00
# date_t2:  2016-12-16 05:00:00
# date_t3:  2016-12-16 06:00:00
#
# processing:  2016-12-16 06:00:00
# date_t1:  2016-12-16 07:00:00
# date_t2:  2016-12-16 08:00:00
# date_t3:  2016-12-16 09:00:00
#
# processing:  2016-12-16 09:00:00
# date_t1:  2016-12-16 10:00:00
# date_t2:  2016-12-16 11:00:00
# date_t3:  2016-12-16 12:00:00
#
# processing:  2016-12-16 12:00:00
# date_t1:  2016-12-16 13:00:00
# date_t2:  2016-12-16 14:00:00
# date_t3:  2016-12-16 15:00:00
#
# processing:  2016-12-16 15:00:00
# date_t1:  2016-12-16 16:00:00
# date_t2:  2016-12-16 17:00:00
# date_t3:  2016-12-16 18:00:00
#
# processing:  2016-12-16 18:00:00
# date_t1:  2016-12-16 19:00:00
# date_t2:  2016-12-16 20:00:00
# date_t3:  2016-12-16 21:00:00
#
# processing:  2016-12-16 21:00:00
# date_t1:  2016-12-16 22:00:00
# date_t2:  2016-12-16 23:00:00
# date_t3:  2016-12-17 00:00:00
#
# processing:  2016-12-17 00:00:00
# date_t1:  2016-12-17 01:00:00
# date_t2:  2016-12-17 02:00:00
# date_t3:  2016-12-17 03:00:00
#
# processing:  2016-12-17 03:00:00
# date_t1:  2016-12-17 04:00:00
# date_t2:  2016-12-17 05:00:00
# date_t3:  2016-12-17 06:00:00
#
# processing:  2016-12-17 06:00:00
# date_t1:  2016-12-17 07:00:00
# date_t2:  2016-12-17 08:00:00
# date_t3:  2016-12-17 09:00:00
#
# processing:  2016-12-17 09:00:00
# date_t1:  2016-12-17 10:00:00
# date_t2:  2016-12-17 11:00:00
# date_t3:  2016-12-17 12:00:00
#
# processing:  2016-12-17 12:00:00
# date_t1:  2016-12-17 13:00:00
# date_t2:  2016-12-17 14:00:00
# date_t3:  2016-12-17 15:00:00
#
# processing:  2016-12-17 15:00:00
# date_t1:  2016-12-17 16:00:00
# date_t2:  2016-12-17 17:00:00
# date_t3:  2016-12-17 18:00:00
#
# processing:  2016-12-17 18:00:00
# date_t1:  2016-12-17 19:00:00
# date_t2:  2016-12-17 20:00:00
# date_t3:  2016-12-17 21:00:00
#
# processing:  2016-12-17 21:00:00
# date_t1:  2016-12-17 22:00:00
# date_t2:  2016-12-17 23:00:00
# date_t3:  2016-12-18 00:00:00
#
# processing:  2016-12-18 00:00:00
# date_t1:  2016-12-18 01:00:00
# date_t2:  2016-12-18 02:00:00
# date_t3:  2016-12-18 03:00:00
#
# processing:  2016-12-18 03:00:00
# date_t1:  2016-12-18 04:00:00
# date_t2:  2016-12-18 05:00:00
# date_t3:  2016-12-18 06:00:00
#
# processing:  2016-12-18 06:00:00
# date_t1:  2016-12-18 07:00:00
# date_t2:  2016-12-18 08:00:00
# date_t3:  2016-12-18 09:00:00
#
# processing:  2016-12-18 09:00:00
# date_t1:  2016-12-18 10:00:00
# date_t2:  2016-12-18 11:00:00
# date_t3:  2016-12-18 12:00:00
#
# processing:  2016-12-18 12:00:00
# date_t1:  2016-12-18 13:00:00
# date_t2:  2016-12-18 14:00:00
# date_t3:  2016-12-18 15:00:00
#
# processing:  2016-12-18 15:00:00
# date_t1:  2016-12-18 16:00:00
# date_t2:  2016-12-18 17:00:00
# date_t3:  2016-12-18 18:00:00
#
# processing:  2016-12-18 18:00:00
# date_t1:  2016-12-18 19:00:00
# date_t2:  2016-12-18 20:00:00
# date_t3:  2016-12-18 21:00:00
#
# processing:  2016-12-18 21:00:00
# date_t1:  2016-12-18 22:00:00
# date_t2:  2016-12-18 23:00:00
# date_t3:  2016-12-19 00:00:00
#
# processing:  2016-12-19 00:00:00
# date_t1:  2016-12-19 01:00:00
# date_t2:  2016-12-19 02:00:00
# date_t3:  2016-12-19 03:00:00
#
# processing:  2016-12-19 03:00:00
# date_t1:  2016-12-19 04:00:00
# date_t2:  2016-12-19 05:00:00
# date_t3:  2016-12-19 06:00:00
#
# processing:  2016-12-19 06:00:00
# date_t1:  2016-12-19 07:00:00
# date_t2:  2016-12-19 08:00:00
# date_t3:  2016-12-19 09:00:00
#
# processing:  2016-12-19 09:00:00
# date_t1:  2016-12-19 10:00:00
# date_t2:  2016-12-19 11:00:00
# date_t3:  2016-12-19 12:00:00
#
# processing:  2016-12-19 12:00:00
# date_t1:  2016-12-19 13:00:00
# date_t2:  2016-12-19 14:00:00
# date_t3:  2016-12-19 15:00:00
#
# processing:  2016-12-19 15:00:00
# date_t1:  2016-12-19 16:00:00
# date_t2:  2016-12-19 17:00:00
# date_t3:  2016-12-19 18:00:00
#
# processing:  2016-12-19 18:00:00
# date_t1:  2016-12-19 19:00:00
# date_t2:  2016-12-19 20:00:00
# date_t3:  2016-12-19 21:00:00
#
# processing:  2016-12-19 21:00:00
# date_t1:  2016-12-19 22:00:00
# date_t2:  2016-12-19 23:00:00
# date_t3:  2016-12-20 00:00:00
#
# processing:  2016-12-20 00:00:00
# date_t1:  2016-12-20 01:00:00
# date_t2:  2016-12-20 02:00:00
# date_t3:  2016-12-20 03:00:00
#
# processing:  2016-12-20 03:00:00
# date_t1:  2016-12-20 04:00:00
# date_t2:  2016-12-20 05:00:00
# date_t3:  2016-12-20 06:00:00
#
# processing:  2016-12-20 06:00:00
# date_t1:  2016-12-20 07:00:00
# date_t2:  2016-12-20 08:00:00
# date_t3:  2016-12-20 09:00:00
#
# processing:  2016-12-20 09:00:00
# date_t1:  2016-12-20 10:00:00
# date_t2:  2016-12-20 11:00:00
# date_t3:  2016-12-20 12:00:00
#
# processing:  2016-12-20 12:00:00
# date_t1:  2016-12-20 13:00:00
# date_t2:  2016-12-20 14:00:00
# date_t3:  2016-12-20 15:00:00
#
# processing:  2016-12-20 15:00:00
# date_t1:  2016-12-20 16:00:00
# date_t2:  2016-12-20 17:00:00
# date_t3:  2016-12-20 18:00:00
#
# processing:  2016-12-20 18:00:00
# date_t1:  2016-12-20 19:00:00
# date_t2:  2016-12-20 20:00:00
# date_t3:  2016-12-20 21:00:00
#
# processing:  2016-12-20 21:00:00
# date_t1:  2016-12-20 22:00:00
# date_t2:  2016-12-20 23:00:00
# date_t3:  2016-12-21 00:00:00
#
# processing:  2016-12-21 00:00:00
# date_t1:  2016-12-21 01:00:00
# date_t2:  2016-12-21 02:00:00
# date_t3:  2016-12-21 03:00:00
#
# processing:  2016-12-21 03:00:00
# date_t1:  2016-12-21 04:00:00
# date_t2:  2016-12-21 05:00:00
# date_t3:  2016-12-21 06:00:00
#
# processing:  2016-12-21 06:00:00
# date_t1:  2016-12-21 07:00:00
# date_t2:  2016-12-21 08:00:00
# date_t3:  2016-12-21 09:00:00
#
# processing:  2016-12-21 09:00:00
# date_t1:  2016-12-21 10:00:00
# date_t2:  2016-12-21 11:00:00
# date_t3:  2016-12-21 12:00:00
#
# processing:  2016-12-21 12:00:00
# date_t1:  2016-12-21 13:00:00
# date_t2:  2016-12-21 14:00:00
# date_t3:  2016-12-21 15:00:00
#
# processing:  2016-12-21 15:00:00
# date_t1:  2016-12-21 16:00:00
# date_t2:  2016-12-21 17:00:00
# date_t3:  2016-12-21 18:00:00
#
# processing:  2016-12-21 18:00:00
# date_t1:  2016-12-21 19:00:00
# date_t2:  2016-12-21 20:00:00
# date_t3:  2016-12-21 21:00:00
#
# processing:  2016-12-21 21:00:00
# date_t1:  2016-12-21 22:00:00
# date_t2:  2016-12-21 23:00:00
# date_t3:  2016-12-22 00:00:00
#
# processing:  2016-12-22 00:00:00
# date_t1:  2016-12-22 01:00:00
# date_t2:  2016-12-22 02:00:00
# date_t3:  2016-12-22 03:00:00
#
# processing:  2016-12-22 03:00:00
# date_t1:  2016-12-22 04:00:00
# date_t2:  2016-12-22 05:00:00
# date_t3:  2016-12-22 06:00:00
#
# processing:  2016-12-22 06:00:00
# date_t1:  2016-12-22 07:00:00
# date_t2:  2016-12-22 08:00:00
# date_t3:  2016-12-22 09:00:00
#
# processing:  2016-12-22 09:00:00
# date_t1:  2016-12-22 10:00:00
# date_t2:  2016-12-22 11:00:00
# date_t3:  2016-12-22 12:00:00
#
# processing:  2016-12-22 12:00:00
# date_t1:  2016-12-22 13:00:00
# date_t2:  2016-12-22 14:00:00
# date_t3:  2016-12-22 15:00:00
#
# processing:  2016-12-22 15:00:00
# date_t1:  2016-12-22 16:00:00
# date_t2:  2016-12-22 17:00:00
# date_t3:  2016-12-22 18:00:00
#
# processing:  2016-12-22 18:00:00
# date_t1:  2016-12-22 19:00:00
# date_t2:  2016-12-22 20:00:00
# date_t3:  2016-12-22 21:00:00

# %%
# df_gt.to_csv("orford_rainfall_gt_clipped.csv")
# X: df_gfs
# Y: df_gt

# %%
col_list = ['pred_cloud_cover', 'pred_cloud_cover_bound_cloud_layer',
       'pred_convective_cloud', 'pred_dewp', 'pred_high_tcc',
       'pred_low_tcc', 'pred_lw_rad', 'pred_max_wind_press',
       'pred_merid_wind', 'pred_middle_tcc', 'pred_rain_rate',
       'pred_rel_humidity', 'pred_sunshine', 'pred_surf_geowind', 'pred_surf_momentum_vflux', 'pred_surface_pressure', 'pred_sw_rad',
       'pred_temp', 'pred_total_rain', 'pred_ustorm', 'pred_vstorm',
       'pred_wind_speed_surf', 'pred_zonal_wind']
df_X = df_gfs[col_list].copy()
df_Y = df_gt.copy()

# %%
# Make sure that df_X is not null
df_X_bool = df_X.isnull().any().any()
print df_X_bool, 'THIS MUST BE FALSE' # This must be FALSE

# df_X.isnull().any()
# Out:
# False THIS MUST BE FALSE

# %%
# df_Y

# %%
# def prepare_lstm_training_test_set(data_matrix, label_matrix):
#     sliding_window = 3
#     tot_samples = data_matrix.shape[0]
#     sample_dimension = data_matrix.shape[1]
#     print "Total Sample: ",tot_samples
#     print "Dimension of each sample: ",sample_dimension
    
#     # Accumulate examples here in this list
#     input_lstm = []
    
#     for sequence in range(0,tot_samples-sliding_window):
#         input_lstm.append(data_matrix[sequence:sequence+sliding_window, :])

# %%
df_data_matrix = df_X.as_matrix()
df_gt_rainfall_forecast_matrix = df_Y.as_matrix()
print 'Shape of data matrix: ',df_data_matrix.shape
print 'Shape of label matrix: ',df_gt_rainfall_forecast_matrix.shape

# Normalize data matrix with zero mean and unit covariance
# http://scikit-learn.org/stable/modules/preprocessing.html
df_data_matrix = preprocessing.scale(df_data_matrix)

data_matrix = np.copy(df_data_matrix)
label_matrix = np.copy(df_gt_rainfall_forecast_matrix)

sliding_window = 3
tot_samples = data_matrix.shape[0]
sample_dimension = data_matrix.shape[1]
print "Total Sample: ",tot_samples
print "Dimension of each sample: ",sample_dimension
    
# Accumulate examples here in this list
input_lstm = []
label_lstm = []
label_entry = sliding_window

    
for sequence in range(0,tot_samples-sliding_window):
    input_lstm.append(data_matrix[sequence:sequence+sliding_window, :])
    label_lstm.append(label_matrix[label_entry,0:3])
    print "sequence, sequence+sliding_window, label_entry: ",sequence,sequence+sliding_window,label_entry
    label_entry = label_entry + 1


return_data_matrix_lstm = np.array(input_lstm)
return_label_matrix_lstm = np.array(label_lstm)

print "LSTM input: ",return_data_matrix_lstm.shape
print "LSTM output: ",return_label_matrix_lstm.shape
# Out:
# Shape of data matrix:  (847L, 23L)
# Shape of label matrix:  (847L, 3L)
# Total Sample:  847
# Dimension of each sample:  23
# sequence, sequence+sliding_window, label_entry:  0 3 3
# sequence, sequence+sliding_window, label_entry:  1 4 4
# sequence, sequence+sliding_window, label_entry:  2 5 5
# sequence, sequence+sliding_window, label_entry:  3 6 6
# sequence, sequence+sliding_window, label_entry:  4 7 7
# sequence, sequence+sliding_window, label_entry:  5 8 8
# sequence, sequence+sliding_window, label_entry:  6 9 9
# sequence, sequence+sliding_window, label_entry:  7 10 10
# sequence, sequence+sliding_window, label_entry:  8 11 11
# sequence, sequence+sliding_window, label_entry:  9 12 12
# sequence, sequence+sliding_window, label_entry:  10 13 13
# sequence, sequence+sliding_window, label_entry:  11 14 14
# sequence, sequence+sliding_window, label_entry:  12 15 15
# sequence, sequence+sliding_window, label_entry:  13 16 16
# sequence, sequence+sliding_window, label_entry:  14 17 17
# sequence, sequence+sliding_window, label_entry:  15 18 18
# sequence, sequence+sliding_window, label_entry:  16 19 19
# sequence, sequence+sliding_window, label_entry:  17 20 20
# sequence, sequence+sliding_window, label_entry:  18 21 21
# sequence, sequence+sliding_window, label_entry:  19 22 22
# sequence, sequence+sliding_window, label_entry:  20 23 23
# sequence, sequence+sliding_window, label_entry:  21 24 24
# sequence, sequence+sliding_window, label_entry:  22 25 25
# sequence, sequence+sliding_window, label_entry:  23 26 26
# sequence, sequence+sliding_window, label_entry:  24 27 27
# sequence, sequence+sliding_window, label_entry:  25 28 28
# sequence, sequence+sliding_window, label_entry:  26 29 29
# sequence, sequence+sliding_window, label_entry:  27 30 30
# sequence, sequence+sliding_window, label_entry:  28 31 31
# sequence, sequence+sliding_window, label_entry:  29 32 32
# sequence, sequence+sliding_window, label_entry:  30 33 33
# sequence, sequence+sliding_window, label_entry:  31 34 34
# sequence, sequence+sliding_window, label_entry:  32 35 35
# sequence, sequence+sliding_window, label_entry:  33 36 36
# sequence, sequence+sliding_window, label_entry:  34 37 37
# sequence, sequence+sliding_window, label_entry:  35 38 38
# sequence, sequence+sliding_window, label_entry:  36 39 39
# sequence, sequence+sliding_window, label_entry:  37 40 40
# sequence, sequence+sliding_window, label_entry:  38 41 41
# sequence, sequence+sliding_window, label_entry:  39 42 42
# sequence, sequence+sliding_window, label_entry:  40 43 43
# sequence, sequence+sliding_window, label_entry:  41 44 44
# sequence, sequence+sliding_window, label_entry:  42 45 45
# sequence, sequence+sliding_window, label_entry:  43 46 46
# sequence, sequence+sliding_window, label_entry:  44 47 47
# sequence, sequence+sliding_window, label_entry:  45 48 48
# sequence, sequence+sliding_window, label_entry:  46 49 49
# sequence, sequence+sliding_window, label_entry:  47 50 50
# sequence, sequence+sliding_window, label_entry:  48 51 51
# sequence, sequence+sliding_window, label_entry:  49 52 52
# sequence, sequence+sliding_window, label_entry:  50 53 53
# sequence, sequence+sliding_window, label_entry:  51 54 54
# sequence, sequence+sliding_window, label_entry:  52 55 55
# sequence, sequence+sliding_window, label_entry:  53 56 56
# sequence, sequence+sliding_window, label_entry:  54 57 57
# sequence, sequence+sliding_window, label_entry:  55 58 58
# sequence, sequence+sliding_window, label_entry:  56 59 59
# sequence, sequence+sliding_window, label_entry:  57 60 60
# sequence, sequence+sliding_window, label_entry:  58 61 61
# sequence, sequence+sliding_window, label_entry:  59 62 62
# sequence, sequence+sliding_window, label_entry:  60 63 63
# sequence, sequence+sliding_window, label_entry:  61 64 64
# sequence, sequence+sliding_window, label_entry:  62 65 65
# sequence, sequence+sliding_window, label_entry:  63 66 66
# sequence, sequence+sliding_window, label_entry:  64 67 67
# sequence, sequence+sliding_window, label_entry:  65 68 68
# sequence, sequence+sliding_window, label_entry:  66 69 69
# sequence, sequence+sliding_window, label_entry:  67 70 70
# sequence, sequence+sliding_window, label_entry:  68 71 71
# sequence, sequence+sliding_window, label_entry:  69 72 72
# sequence, sequence+sliding_window, label_entry:  70 73 73
# sequence, sequence+sliding_window, label_entry:  71 74 74
# sequence, sequence+sliding_window, label_entry:  72 75 75
# sequence, sequence+sliding_window, label_entry:  73 76 76
# sequence, sequence+sliding_window, label_entry:  74 77 77
# sequence, sequence+sliding_window, label_entry:  75 78 78
# sequence, sequence+sliding_window, label_entry:  76 79 79
# sequence, sequence+sliding_window, label_entry:  77 80 80
# sequence, sequence+sliding_window, label_entry:  78 81 81
# sequence, sequence+sliding_window, label_entry:  79 82 82
# sequence, sequence+sliding_window, label_entry:  80 83 83
# sequence, sequence+sliding_window, label_entry:  81 84 84
# sequence, sequence+sliding_window, label_entry:  82 85 85
# sequence, sequence+sliding_window, label_entry:  83 86 86
# sequence, sequence+sliding_window, label_entry:  84 87 87
# sequence, sequence+sliding_window, label_entry:  85 88 88
# sequence, sequence+sliding_window, label_entry:  86 89 89
# sequence, sequence+sliding_window, label_entry:  87 90 90
# sequence, sequence+sliding_window, label_entry:  88 91 91
# sequence, sequence+sliding_window, label_entry:  89 92 92
# sequence, sequence+sliding_window, label_entry:  90 93 93
# sequence, sequence+sliding_window, label_entry:  91 94 94
# sequence, sequence+sliding_window, label_entry:  92 95 95
# sequence, sequence+sliding_window, label_entry:  93 96 96
# sequence, sequence+sliding_window, label_entry:  94 97 97
# sequence, sequence+sliding_window, label_entry:  95 98 98
# sequence, sequence+sliding_window, label_entry:  96 99 99
# sequence, sequence+sliding_window, label_entry:  97 100 100
# sequence, sequence+sliding_window, label_entry:  98 101 101
# sequence, sequence+sliding_window, label_entry:  99 102 102
# sequence, sequence+sliding_window, label_entry:  100 103 103
# sequence, sequence+sliding_window, label_entry:  101 104 104
# sequence, sequence+sliding_window, label_entry:  102 105 105
# sequence, sequence+sliding_window, label_entry:  103 106 106
# sequence, sequence+sliding_window, label_entry:  104 107 107
# sequence, sequence+sliding_window, label_entry:  105 108 108
# sequence, sequence+sliding_window, label_entry:  106 109 109
# sequence, sequence+sliding_window, label_entry:  107 110 110
# sequence, sequence+sliding_window, label_entry:  108 111 111
# sequence, sequence+sliding_window, label_entry:  109 112 112
# sequence, sequence+sliding_window, label_entry:  110 113 113
# sequence, sequence+sliding_window, label_entry:  111 114 114
# sequence, sequence+sliding_window, label_entry:  112 115 115
# sequence, sequence+sliding_window, label_entry:  113 116 116
# sequence, sequence+sliding_window, label_entry:  114 117 117
# sequence, sequence+sliding_window, label_entry:  115 118 118
# sequence, sequence+sliding_window, label_entry:  116 119 119
# sequence, sequence+sliding_window, label_entry:  117 120 120
# sequence, sequence+sliding_window, label_entry:  118 121 121
# sequence, sequence+sliding_window, label_entry:  119 122 122
# sequence, sequence+sliding_window, label_entry:  120 123 123
# sequence, sequence+sliding_window, label_entry:  121 124 124
# sequence, sequence+sliding_window, label_entry:  122 125 125
# sequence, sequence+sliding_window, label_entry:  123 126 126
# sequence, sequence+sliding_window, label_entry:  124 127 127
# sequence, sequence+sliding_window, label_entry:  125 128 128
# sequence, sequence+sliding_window, label_entry:  126 129 129
# sequence, sequence+sliding_window, label_entry:  127 130 130
# sequence, sequence+sliding_window, label_entry:  128 131 131
# sequence, sequence+sliding_window, label_entry:  129 132 132
# sequence, sequence+sliding_window, label_entry:  130 133 133
# sequence, sequence+sliding_window, label_entry:  131 134 134
# sequence, sequence+sliding_window, label_entry:  132 135 135
# sequence, sequence+sliding_window, label_entry:  133 136 136
# sequence, sequence+sliding_window, label_entry:  134 137 137
# sequence, sequence+sliding_window, label_entry:  135 138 138
# sequence, sequence+sliding_window, label_entry:  136 139 139
# sequence, sequence+sliding_window, label_entry:  137 140 140
# sequence, sequence+sliding_window, label_entry:  138 141 141
# sequence, sequence+sliding_window, label_entry:  139 142 142
# sequence, sequence+sliding_window, label_entry:  140 143 143
# sequence, sequence+sliding_window, label_entry:  141 144 144
# sequence, sequence+sliding_window, label_entry:  142 145 145
# sequence, sequence+sliding_window, label_entry:  143 146 146
# sequence, sequence+sliding_window, label_entry:  144 147 147
# sequence, sequence+sliding_window, label_entry:  145 148 148
# sequence, sequence+sliding_window, label_entry:  146 149 149
# sequence, sequence+sliding_window, label_entry:  147 150 150
# sequence, sequence+sliding_window, label_entry:  148 151 151
# sequence, sequence+sliding_window, label_entry:  149 152 152
# sequence, sequence+sliding_window, label_entry:  150 153 153
# sequence, sequence+sliding_window, label_entry:  151 154 154
# sequence, sequence+sliding_window, label_entry:  152 155 155
# sequence, sequence+sliding_window, label_entry:  153 156 156
# sequence, sequence+sliding_window, label_entry:  154 157 157
# sequence, sequence+sliding_window, label_entry:  155 158 158
# sequence, sequence+sliding_window, label_entry:  156 159 159
# sequence, sequence+sliding_window, label_entry:  157 160 160
# sequence, sequence+sliding_window, label_entry:  158 161 161
# sequence, sequence+sliding_window, label_entry:  159 162 162
# sequence, sequence+sliding_window, label_entry:  160 163 163
# sequence, sequence+sliding_window, label_entry:  161 164 164
# sequence, sequence+sliding_window, label_entry:  162 165 165
# sequence, sequence+sliding_window, label_entry:  163 166 166
# sequence, sequence+sliding_window, label_entry:  164 167 167
# sequence, sequence+sliding_window, label_entry:  165 168 168
# sequence, sequence+sliding_window, label_entry:  166 169 169
# sequence, sequence+sliding_window, label_entry:  167 170 170
# sequence, sequence+sliding_window, label_entry:  168 171 171
# sequence, sequence+sliding_window, label_entry:  169 172 172
# sequence, sequence+sliding_window, label_entry:  170 173 173
# sequence, sequence+sliding_window, label_entry:  171 174 174
# sequence, sequence+sliding_window, label_entry:  172 175 175
# sequence, sequence+sliding_window, label_entry:  173 176 176
# sequence, sequence+sliding_window, label_entry:  174 177 177
# sequence, sequence+sliding_window, label_entry:  175 178 178
# sequence, sequence+sliding_window, label_entry:  176 179 179
# sequence, sequence+sliding_window, label_entry:  177 180 180
# sequence, sequence+sliding_window, label_entry:  178 181 181
# sequence, sequence+sliding_window, label_entry:  179 182 182
# sequence, sequence+sliding_window, label_entry:  180 183 183
# sequence, sequence+sliding_window, label_entry:  181 184 184
# sequence, sequence+sliding_window, label_entry:  182 185 185
# sequence, sequence+sliding_window, label_entry:  183 186 186
# sequence, sequence+sliding_window, label_entry:  184 187 187
# sequence, sequence+sliding_window, label_entry:  185 188 188
# sequence, sequence+sliding_window, label_entry:  186 189 189
# sequence, sequence+sliding_window, label_entry:  187 190 190
# sequence, sequence+sliding_window, label_entry:  188 191 191
# sequence, sequence+sliding_window, label_entry:  189 192 192
# sequence, sequence+sliding_window, label_entry:  190 193 193
# sequence, sequence+sliding_window, label_entry:  191 194 194
# sequence, sequence+sliding_window, label_entry:  192 195 195
# sequence, sequence+sliding_window, label_entry:  193 196 196
# sequence, sequence+sliding_window, label_entry:  194 197 197
# sequence, sequence+sliding_window, label_entry:  195 198 198
# sequence, sequence+sliding_window, label_entry:  196 199 199
# sequence, sequence+sliding_window, label_entry:  197 200 200
# sequence, sequence+sliding_window, label_entry:  198 201 201
# sequence, sequence+sliding_window, label_entry:  199 202 202
# sequence, sequence+sliding_window, label_entry:  200 203 203
# sequence, sequence+sliding_window, label_entry:  201 204 204
# sequence, sequence+sliding_window, label_entry:  202 205 205
# sequence, sequence+sliding_window, label_entry:  203 206 206
# sequence, sequence+sliding_window, label_entry:  204 207 207
# sequence, sequence+sliding_window, label_entry:  205 208 208
# sequence, sequence+sliding_window, label_entry:  206 209 209
# sequence, sequence+sliding_window, label_entry:  207 210 210
# sequence, sequence+sliding_window, label_entry:  208 211 211
# sequence, sequence+sliding_window, label_entry:  209 212 212
# sequence, sequence+sliding_window, label_entry:  210 213 213
# sequence, sequence+sliding_window, label_entry:  211 214 214
# sequence, sequence+sliding_window, label_entry:  212 215 215
# sequence, sequence+sliding_window, label_entry:  213 216 216
# sequence, sequence+sliding_window, label_entry:  214 217 217
# sequence, sequence+sliding_window, label_entry:  215 218 218
# sequence, sequence+sliding_window, label_entry:  216 219 219
# sequence, sequence+sliding_window, label_entry:  217 220 220
# sequence, sequence+sliding_window, label_entry:  218 221 221
# sequence, sequence+sliding_window, label_entry:  219 222 222
# sequence, sequence+sliding_window, label_entry:  220 223 223
# sequence, sequence+sliding_window, label_entry:  221 224 224
# sequence, sequence+sliding_window, label_entry:  222 225 225
# sequence, sequence+sliding_window, label_entry:  223 226 226
# sequence, sequence+sliding_window, label_entry:  224 227 227
# sequence, sequence+sliding_window, label_entry:  225 228 228
# sequence, sequence+sliding_window, label_entry:  226 229 229
# sequence, sequence+sliding_window, label_entry:  227 230 230
# sequence, sequence+sliding_window, label_entry:  228 231 231
# sequence, sequence+sliding_window, label_entry:  229 232 232
# sequence, sequence+sliding_window, label_entry:  230 233 233
# sequence, sequence+sliding_window, label_entry:  231 234 234
# sequence, sequence+sliding_window, label_entry:  232 235 235
# sequence, sequence+sliding_window, label_entry:  233 236 236
# sequence, sequence+sliding_window, label_entry:  234 237 237
# sequence, sequence+sliding_window, label_entry:  235 238 238
# sequence, sequence+sliding_window, label_entry:  236 239 239
# sequence, sequence+sliding_window, label_entry:  237 240 240
# sequence, sequence+sliding_window, label_entry:  238 241 241
# sequence, sequence+sliding_window, label_entry:  239 242 242
# sequence, sequence+sliding_window, label_entry:  240 243 243
# sequence, sequence+sliding_window, label_entry:  241 244 244
# sequence, sequence+sliding_window, label_entry:  242 245 245
# sequence, sequence+sliding_window, label_entry:  243 246 246
# sequence, sequence+sliding_window, label_entry:  244 247 247
# sequence, sequence+sliding_window, label_entry:  245 248 248
# sequence, sequence+sliding_window, label_entry:  246 249 249
# sequence, sequence+sliding_window, label_entry:  247 250 250
# sequence, sequence+sliding_window, label_entry:  248 251 251
# sequence, sequence+sliding_window, label_entry:  249 252 252
# sequence, sequence+sliding_window, label_entry:  250 253 253
# sequence, sequence+sliding_window, label_entry:  251 254 254
# sequence, sequence+sliding_window, label_entry:  252 255 255
# sequence, sequence+sliding_window, label_entry:  253 256 256
# sequence, sequence+sliding_window, label_entry:  254 257 257
# sequence, sequence+sliding_window, label_entry:  255 258 258
# sequence, sequence+sliding_window, label_entry:  256 259 259
# sequence, sequence+sliding_window, label_entry:  257 260 260
# sequence, sequence+sliding_window, label_entry:  258 261 261
# sequence, sequence+sliding_window, label_entry:  259 262 262
# sequence, sequence+sliding_window, label_entry:  260 263 263
# sequence, sequence+sliding_window, label_entry:  261 264 264
# sequence, sequence+sliding_window, label_entry:  262 265 265
# sequence, sequence+sliding_window, label_entry:  263 266 266
# sequence, sequence+sliding_window, label_entry:  264 267 267
# sequence, sequence+sliding_window, label_entry:  265 268 268
# sequence, sequence+sliding_window, label_entry:  266 269 269
# sequence, sequence+sliding_window, label_entry:  267 270 270
# sequence, sequence+sliding_window, label_entry:  268 271 271
# sequence, sequence+sliding_window, label_entry:  269 272 272
# sequence, sequence+sliding_window, label_entry:  270 273 273
# sequence, sequence+sliding_window, label_entry:  271 274 274
# sequence, sequence+sliding_window, label_entry:  272 275 275
# sequence, sequence+sliding_window, label_entry:  273 276 276
# sequence, sequence+sliding_window, label_entry:  274 277 277
# sequence, sequence+sliding_window, label_entry:  275 278 278
# sequence, sequence+sliding_window, label_entry:  276 279 279
# sequence, sequence+sliding_window, label_entry:  277 280 280
# sequence, sequence+sliding_window, label_entry:  278 281 281
# sequence, sequence+sliding_window, label_entry:  279 282 282
# sequence, sequence+sliding_window, label_entry:  280 283 283
# sequence, sequence+sliding_window, label_entry:  281 284 284
# sequence, sequence+sliding_window, label_entry:  282 285 285
# sequence, sequence+sliding_window, label_entry:  283 286 286
# sequence, sequence+sliding_window, label_entry:  284 287 287
# sequence, sequence+sliding_window, label_entry:  285 288 288
# sequence, sequence+sliding_window, label_entry:  286 289 289
# sequence, sequence+sliding_window, label_entry:  287 290 290
# sequence, sequence+sliding_window, label_entry:  288 291 291
# sequence, sequence+sliding_window, label_entry:  289 292 292
# sequence, sequence+sliding_window, label_entry:  290 293 293
# sequence, sequence+sliding_window, label_entry:  291 294 294
# sequence, sequence+sliding_window, label_entry:  292 295 295
# sequence, sequence+sliding_window, label_entry:  293 296 296
# sequence, sequence+sliding_window, label_entry:  294 297 297
# sequence, sequence+sliding_window, label_entry:  295 298 298
# sequence, sequence+sliding_window, label_entry:  296 299 299
# sequence, sequence+sliding_window, label_entry:  297 300 300
# sequence, sequence+sliding_window, label_entry:  298 301 301
# sequence, sequence+sliding_window, label_entry:  299 302 302
# sequence, sequence+sliding_window, label_entry:  300 303 303
# sequence, sequence+sliding_window, label_entry:  301 304 304
# sequence, sequence+sliding_window, label_entry:  302 305 305
# sequence, sequence+sliding_window, label_entry:  303 306 306
# sequence, sequence+sliding_window, label_entry:  304 307 307
# sequence, sequence+sliding_window, label_entry:  305 308 308
# sequence, sequence+sliding_window, label_entry:  306 309 309
# sequence, sequence+sliding_window, label_entry:  307 310 310
# sequence, sequence+sliding_window, label_entry:  308 311 311
# sequence, sequence+sliding_window, label_entry:  309 312 312
# sequence, sequence+sliding_window, label_entry:  310 313 313
# sequence, sequence+sliding_window, label_entry:  311 314 314
# sequence, sequence+sliding_window, label_entry:  312 315 315
# sequence, sequence+sliding_window, label_entry:  313 316 316
# sequence, sequence+sliding_window, label_entry:  314 317 317
# sequence, sequence+sliding_window, label_entry:  315 318 318
# sequence, sequence+sliding_window, label_entry:  316 319 319
# sequence, sequence+sliding_window, label_entry:  317 320 320
# sequence, sequence+sliding_window, label_entry:  318 321 321
# sequence, sequence+sliding_window, label_entry:  319 322 322
# sequence, sequence+sliding_window, label_entry:  320 323 323
# sequence, sequence+sliding_window, label_entry:  321 324 324
# sequence, sequence+sliding_window, label_entry:  322 325 325
# sequence, sequence+sliding_window, label_entry:  323 326 326
# sequence, sequence+sliding_window, label_entry:  324 327 327
# sequence, sequence+sliding_window, label_entry:  325 328 328
# sequence, sequence+sliding_window, label_entry:  326 329 329
# sequence, sequence+sliding_window, label_entry:  327 330 330
# sequence, sequence+sliding_window, label_entry:  328 331 331
# sequence, sequence+sliding_window, label_entry:  329 332 332
# sequence, sequence+sliding_window, label_entry:  330 333 333
# sequence, sequence+sliding_window, label_entry:  331 334 334
# sequence, sequence+sliding_window, label_entry:  332 335 335
# sequence, sequence+sliding_window, label_entry:  333 336 336
# sequence, sequence+sliding_window, label_entry:  334 337 337
# sequence, sequence+sliding_window, label_entry:  335 338 338
# sequence, sequence+sliding_window, label_entry:  336 339 339
# sequence, sequence+sliding_window, label_entry:  337 340 340
# sequence, sequence+sliding_window, label_entry:  338 341 341
# sequence, sequence+sliding_window, label_entry:  339 342 342
# sequence, sequence+sliding_window, label_entry:  340 343 343
# sequence, sequence+sliding_window, label_entry:  341 344 344
# sequence, sequence+sliding_window, label_entry:  342 345 345
# sequence, sequence+sliding_window, label_entry:  343 346 346
# sequence, sequence+sliding_window, label_entry:  344 347 347
# sequence, sequence+sliding_window, label_entry:  345 348 348
# sequence, sequence+sliding_window, label_entry:  346 349 349
# sequence, sequence+sliding_window, label_entry:  347 350 350
# sequence, sequence+sliding_window, label_entry:  348 351 351
# sequence, sequence+sliding_window, label_entry:  349 352 352
# sequence, sequence+sliding_window, label_entry:  350 353 353
# sequence, sequence+sliding_window, label_entry:  351 354 354
# sequence, sequence+sliding_window, label_entry:  352 355 355
# sequence, sequence+sliding_window, label_entry:  353 356 356
# sequence, sequence+sliding_window, label_entry:  354 357 357
# sequence, sequence+sliding_window, label_entry:  355 358 358
# sequence, sequence+sliding_window, label_entry:  356 359 359
# sequence, sequence+sliding_window, label_entry:  357 360 360
# sequence, sequence+sliding_window, label_entry:  358 361 361
# sequence, sequence+sliding_window, label_entry:  359 362 362
# sequence, sequence+sliding_window, label_entry:  360 363 363
# sequence, sequence+sliding_window, label_entry:  361 364 364
# sequence, sequence+sliding_window, label_entry:  362 365 365
# sequence, sequence+sliding_window, label_entry:  363 366 366
# sequence, sequence+sliding_window, label_entry:  364 367 367
# sequence, sequence+sliding_window, label_entry:  365 368 368
# sequence, sequence+sliding_window, label_entry:  366 369 369
# sequence, sequence+sliding_window, label_entry:  367 370 370
# sequence, sequence+sliding_window, label_entry:  368 371 371
# sequence, sequence+sliding_window, label_entry:  369 372 372
# sequence, sequence+sliding_window, label_entry:  370 373 373
# sequence, sequence+sliding_window, label_entry:  371 374 374
# sequence, sequence+sliding_window, label_entry:  372 375 375
# sequence, sequence+sliding_window, label_entry:  373 376 376
# sequence, sequence+sliding_window, label_entry:  374 377 377
# sequence, sequence+sliding_window, label_entry:  375 378 378
# sequence, sequence+sliding_window, label_entry:  376 379 379
# sequence, sequence+sliding_window, label_entry:  377 380 380
# sequence, sequence+sliding_window, label_entry:  378 381 381
# sequence, sequence+sliding_window, label_entry:  379 382 382
# sequence, sequence+sliding_window, label_entry:  380 383 383
# sequence, sequence+sliding_window, label_entry:  381 384 384
# sequence, sequence+sliding_window, label_entry:  382 385 385
# sequence, sequence+sliding_window, label_entry:  383 386 386
# sequence, sequence+sliding_window, label_entry:  384 387 387
# sequence, sequence+sliding_window, label_entry:  385 388 388
# sequence, sequence+sliding_window, label_entry:  386 389 389
# sequence, sequence+sliding_window, label_entry:  387 390 390
# sequence, sequence+sliding_window, label_entry:  388 391 391
# sequence, sequence+sliding_window, label_entry:  389 392 392
# sequence, sequence+sliding_window, label_entry:  390 393 393
# sequence, sequence+sliding_window, label_entry:  391 394 394
# sequence, sequence+sliding_window, label_entry:  392 395 395
# sequence, sequence+sliding_window, label_entry:  393 396 396
# sequence, sequence+sliding_window, label_entry:  394 397 397
# sequence, sequence+sliding_window, label_entry:  395 398 398
# sequence, sequence+sliding_window, label_entry:  396 399 399
# sequence, sequence+sliding_window, label_entry:  397 400 400
# sequence, sequence+sliding_window, label_entry:  398 401 401
# sequence, sequence+sliding_window, label_entry:  399 402 402
# sequence, sequence+sliding_window, label_entry:  400 403 403
# sequence, sequence+sliding_window, label_entry:  401 404 404
# sequence, sequence+sliding_window, label_entry:  402 405 405
# sequence, sequence+sliding_window, label_entry:  403 406 406
# sequence, sequence+sliding_window, label_entry:  404 407 407
# sequence, sequence+sliding_window, label_entry:  405 408 408
# sequence, sequence+sliding_window, label_entry:  406 409 409
# sequence, sequence+sliding_window, label_entry:  407 410 410
# sequence, sequence+sliding_window, label_entry:  408 411 411
# sequence, sequence+sliding_window, label_entry:  409 412 412
# sequence, sequence+sliding_window, label_entry:  410 413 413
# sequence, sequence+sliding_window, label_entry:  411 414 414
# sequence, sequence+sliding_window, label_entry:  412 415 415
# sequence, sequence+sliding_window, label_entry:  413 416 416
# sequence, sequence+sliding_window, label_entry:  414 417 417
# sequence, sequence+sliding_window, label_entry:  415 418 418
# sequence, sequence+sliding_window, label_entry:  416 419 419
# sequence, sequence+sliding_window, label_entry:  417 420 420
# sequence, sequence+sliding_window, label_entry:  418 421 421
# sequence, sequence+sliding_window, label_entry:  419 422 422
# sequence, sequence+sliding_window, label_entry:  420 423 423
# sequence, sequence+sliding_window, label_entry:  421 424 424
# sequence, sequence+sliding_window, label_entry:  422 425 425
# sequence, sequence+sliding_window, label_entry:  423 426 426
# sequence, sequence+sliding_window, label_entry:  424 427 427
# sequence, sequence+sliding_window, label_entry:  425 428 428
# sequence, sequence+sliding_window, label_entry:  426 429 429
# sequence, sequence+sliding_window, label_entry:  427 430 430
# sequence, sequence+sliding_window, label_entry:  428 431 431
# sequence, sequence+sliding_window, label_entry:  429 432 432
# sequence, sequence+sliding_window, label_entry:  430 433 433
# sequence, sequence+sliding_window, label_entry:  431 434 434
# sequence, sequence+sliding_window, label_entry:  432 435 435
# sequence, sequence+sliding_window, label_entry:  433 436 436
# sequence, sequence+sliding_window, label_entry:  434 437 437
# sequence, sequence+sliding_window, label_entry:  435 438 438
# sequence, sequence+sliding_window, label_entry:  436 439 439
# sequence, sequence+sliding_window, label_entry:  437 440 440
# sequence, sequence+sliding_window, label_entry:  438 441 441
# sequence, sequence+sliding_window, label_entry:  439 442 442
# sequence, sequence+sliding_window, label_entry:  440 443 443
# sequence, sequence+sliding_window, label_entry:  441 444 444
# sequence, sequence+sliding_window, label_entry:  442 445 445
# sequence, sequence+sliding_window, label_entry:  443 446 446
# sequence, sequence+sliding_window, label_entry:  444 447 447
# sequence, sequence+sliding_window, label_entry:  445 448 448
# sequence, sequence+sliding_window, label_entry:  446 449 449
# sequence, sequence+sliding_window, label_entry:  447 450 450
# sequence, sequence+sliding_window, label_entry:  448 451 451
# sequence, sequence+sliding_window, label_entry:  449 452 452
# sequence, sequence+sliding_window, label_entry:  450 453 453
# sequence, sequence+sliding_window, label_entry:  451 454 454
# sequence, sequence+sliding_window, label_entry:  452 455 455
# sequence, sequence+sliding_window, label_entry:  453 456 456
# sequence, sequence+sliding_window, label_entry:  454 457 457
# sequence, sequence+sliding_window, label_entry:  455 458 458
# sequence, sequence+sliding_window, label_entry:  456 459 459
# sequence, sequence+sliding_window, label_entry:  457 460 460
# sequence, sequence+sliding_window, label_entry:  458 461 461
# sequence, sequence+sliding_window, label_entry:  459 462 462
# sequence, sequence+sliding_window, label_entry:  460 463 463
# sequence, sequence+sliding_window, label_entry:  461 464 464
# sequence, sequence+sliding_window, label_entry:  462 465 465
# sequence, sequence+sliding_window, label_entry:  463 466 466
# sequence, sequence+sliding_window, label_entry:  464 467 467
# sequence, sequence+sliding_window, label_entry:  465 468 468
# sequence, sequence+sliding_window, label_entry:  466 469 469
# sequence, sequence+sliding_window, label_entry:  467 470 470
# sequence, sequence+sliding_window, label_entry:  468 471 471
# sequence, sequence+sliding_window, label_entry:  469 472 472
# sequence, sequence+sliding_window, label_entry:  470 473 473
# sequence, sequence+sliding_window, label_entry:  471 474 474
# sequence, sequence+sliding_window, label_entry:  472 475 475
# sequence, sequence+sliding_window, label_entry:  473 476 476
# sequence, sequence+sliding_window, label_entry:  474 477 477
# sequence, sequence+sliding_window, label_entry:  475 478 478
# sequence, sequence+sliding_window, label_entry:  476 479 479
# sequence, sequence+sliding_window, label_entry:  477 480 480
# sequence, sequence+sliding_window, label_entry:  478 481 481
# sequence, sequence+sliding_window, label_entry:  479 482 482
# sequence, sequence+sliding_window, label_entry:  480 483 483
# sequence, sequence+sliding_window, label_entry:  481 484 484
# sequence, sequence+sliding_window, label_entry:  482 485 485
# sequence, sequence+sliding_window, label_entry:  483 486 486
# sequence, sequence+sliding_window, label_entry:  484 487 487
# sequence, sequence+sliding_window, label_entry:  485 488 488
# sequence, sequence+sliding_window, label_entry:  486 489 489
# sequence, sequence+sliding_window, label_entry:  487 490 490
# sequence, sequence+sliding_window, label_entry:  488 491 491
# sequence, sequence+sliding_window, label_entry:  489 492 492
# sequence, sequence+sliding_window, label_entry:  490 493 493
# sequence, sequence+sliding_window, label_entry:  491 494 494
# sequence, sequence+sliding_window, label_entry:  492 495 495
# sequence, sequence+sliding_window, label_entry:  493 496 496
# sequence, sequence+sliding_window, label_entry:  494 497 497
# sequence, sequence+sliding_window, label_entry:  495 498 498
# sequence, sequence+sliding_window, label_entry:  496 499 499
# sequence, sequence+sliding_window, label_entry:  497 500 500
# sequence, sequence+sliding_window, label_entry:  498 501 501
# sequence, sequence+sliding_window, label_entry:  499 502 502
# sequence, sequence+sliding_window, label_entry:  500 503 503
# sequence, sequence+sliding_window, label_entry:  501 504 504
# sequence, sequence+sliding_window, label_entry:  502 505 505
# sequence, sequence+sliding_window, label_entry:  503 506 506
# sequence, sequence+sliding_window, label_entry:  504 507 507
# sequence, sequence+sliding_window, label_entry:  505 508 508
# sequence, sequence+sliding_window, label_entry:  506 509 509
# sequence, sequence+sliding_window, label_entry:  507 510 510
# sequence, sequence+sliding_window, label_entry:  508 511 511
# sequence, sequence+sliding_window, label_entry:  509 512 512
# sequence, sequence+sliding_window, label_entry:  510 513 513
# sequence, sequence+sliding_window, label_entry:  511 514 514
# sequence, sequence+sliding_window, label_entry:  512 515 515
# sequence, sequence+sliding_window, label_entry:  513 516 516
# sequence, sequence+sliding_window, label_entry:  514 517 517
# sequence, sequence+sliding_window, label_entry:  515 518 518
# sequence, sequence+sliding_window, label_entry:  516 519 519
# sequence, sequence+sliding_window, label_entry:  517 520 520
# sequence, sequence+sliding_window, label_entry:  518 521 521
# sequence, sequence+sliding_window, label_entry:  519 522 522
# sequence, sequence+sliding_window, label_entry:  520 523 523
# sequence, sequence+sliding_window, label_entry:  521 524 524
# sequence, sequence+sliding_window, label_entry:  522 525 525
# sequence, sequence+sliding_window, label_entry:  523 526 526
# sequence, sequence+sliding_window, label_entry:  524 527 527
# sequence, sequence+sliding_window, label_entry:  525 528 528
# sequence, sequence+sliding_window, label_entry:  526 529 529
# sequence, sequence+sliding_window, label_entry:  527 530 530
# sequence, sequence+sliding_window, label_entry:  528 531 531
# sequence, sequence+sliding_window, label_entry:  529 532 532
# sequence, sequence+sliding_window, label_entry:  530 533 533
# sequence, sequence+sliding_window, label_entry:  531 534 534
# sequence, sequence+sliding_window, label_entry:  532 535 535
# sequence, sequence+sliding_window, label_entry:  533 536 536
# sequence, sequence+sliding_window, label_entry:  534 537 537
# sequence, sequence+sliding_window, label_entry:  535 538 538
# sequence, sequence+sliding_window, label_entry:  536 539 539
# sequence, sequence+sliding_window, label_entry:  537 540 540
# sequence, sequence+sliding_window, label_entry:  538 541 541
# sequence, sequence+sliding_window, label_entry:  539 542 542
# sequence, sequence+sliding_window, label_entry:  540 543 543
# sequence, sequence+sliding_window, label_entry:  541 544 544
# sequence, sequence+sliding_window, label_entry:  542 545 545
# sequence, sequence+sliding_window, label_entry:  543 546 546
# sequence, sequence+sliding_window, label_entry:  544 547 547
# sequence, sequence+sliding_window, label_entry:  545 548 548
# sequence, sequence+sliding_window, label_entry:  546 549 549
# sequence, sequence+sliding_window, label_entry:  547 550 550
# sequence, sequence+sliding_window, label_entry:  548 551 551
# sequence, sequence+sliding_window, label_entry:  549 552 552
# sequence, sequence+sliding_window, label_entry:  550 553 553
# sequence, sequence+sliding_window, label_entry:  551 554 554
# sequence, sequence+sliding_window, label_entry:  552 555 555
# sequence, sequence+sliding_window, label_entry:  553 556 556
# sequence, sequence+sliding_window, label_entry:  554 557 557
# sequence, sequence+sliding_window, label_entry:  555 558 558
# sequence, sequence+sliding_window, label_entry:  556 559 559
# sequence, sequence+sliding_window, label_entry:  557 560 560
# sequence, sequence+sliding_window, label_entry:  558 561 561
# sequence, sequence+sliding_window, label_entry:  559 562 562
# sequence, sequence+sliding_window, label_entry:  560 563 563
# sequence, sequence+sliding_window, label_entry:  561 564 564
# sequence, sequence+sliding_window, label_entry:  562 565 565
# sequence, sequence+sliding_window, label_entry:  563 566 566
# sequence, sequence+sliding_window, label_entry:  564 567 567
# sequence, sequence+sliding_window, label_entry:  565 568 568
# sequence, sequence+sliding_window, label_entry:  566 569 569
# sequence, sequence+sliding_window, label_entry:  567 570 570
# sequence, sequence+sliding_window, label_entry:  568 571 571
# sequence, sequence+sliding_window, label_entry:  569 572 572
# sequence, sequence+sliding_window, label_entry:  570 573 573
# sequence, sequence+sliding_window, label_entry:  571 574 574
# sequence, sequence+sliding_window, label_entry:  572 575 575
# sequence, sequence+sliding_window, label_entry:  573 576 576
# sequence, sequence+sliding_window, label_entry:  574 577 577
# sequence, sequence+sliding_window, label_entry:  575 578 578
# sequence, sequence+sliding_window, label_entry:  576 579 579
# sequence, sequence+sliding_window, label_entry:  577 580 580
# sequence, sequence+sliding_window, label_entry:  578 581 581
# sequence, sequence+sliding_window, label_entry:  579 582 582
# sequence, sequence+sliding_window, label_entry:  580 583 583
# sequence, sequence+sliding_window, label_entry:  581 584 584
# sequence, sequence+sliding_window, label_entry:  582 585 585
# sequence, sequence+sliding_window, label_entry:  583 586 586
# sequence, sequence+sliding_window, label_entry:  584 587 587
# sequence, sequence+sliding_window, label_entry:  585 588 588
# sequence, sequence+sliding_window, label_entry:  586 589 589
# sequence, sequence+sliding_window, label_entry:  587 590 590
# sequence, sequence+sliding_window, label_entry:  588 591 591
# sequence, sequence+sliding_window, label_entry:  589 592 592
# sequence, sequence+sliding_window, label_entry:  590 593 593
# sequence, sequence+sliding_window, label_entry:  591 594 594
# sequence, sequence+sliding_window, label_entry:  592 595 595
# sequence, sequence+sliding_window, label_entry:  593 596 596
# sequence, sequence+sliding_window, label_entry:  594 597 597
# sequence, sequence+sliding_window, label_entry:  595 598 598
# sequence, sequence+sliding_window, label_entry:  596 599 599
# sequence, sequence+sliding_window, label_entry:  597 600 600
# sequence, sequence+sliding_window, label_entry:  598 601 601
# sequence, sequence+sliding_window, label_entry:  599 602 602
# sequence, sequence+sliding_window, label_entry:  600 603 603
# sequence, sequence+sliding_window, label_entry:  601 604 604
# sequence, sequence+sliding_window, label_entry:  602 605 605
# sequence, sequence+sliding_window, label_entry:  603 606 606
# sequence, sequence+sliding_window, label_entry:  604 607 607
# sequence, sequence+sliding_window, label_entry:  605 608 608
# sequence, sequence+sliding_window, label_entry:  606 609 609
# sequence, sequence+sliding_window, label_entry:  607 610 610
# sequence, sequence+sliding_window, label_entry:  608 611 611
# sequence, sequence+sliding_window, label_entry:  609 612 612
# sequence, sequence+sliding_window, label_entry:  610 613 613
# sequence, sequence+sliding_window, label_entry:  611 614 614
# sequence, sequence+sliding_window, label_entry:  612 615 615
# sequence, sequence+sliding_window, label_entry:  613 616 616
# sequence, sequence+sliding_window, label_entry:  614 617 617
# sequence, sequence+sliding_window, label_entry:  615 618 618
# sequence, sequence+sliding_window, label_entry:  616 619 619
# sequence, sequence+sliding_window, label_entry:  617 620 620
# sequence, sequence+sliding_window, label_entry:  618 621 621
# sequence, sequence+sliding_window, label_entry:  619 622 622
# sequence, sequence+sliding_window, label_entry:  620 623 623
# sequence, sequence+sliding_window, label_entry:  621 624 624
# sequence, sequence+sliding_window, label_entry:  622 625 625
# sequence, sequence+sliding_window, label_entry:  623 626 626
# sequence, sequence+sliding_window, label_entry:  624 627 627
# sequence, sequence+sliding_window, label_entry:  625 628 628
# sequence, sequence+sliding_window, label_entry:  626 629 629
# sequence, sequence+sliding_window, label_entry:  627 630 630
# sequence, sequence+sliding_window, label_entry:  628 631 631
# sequence, sequence+sliding_window, label_entry:  629 632 632
# sequence, sequence+sliding_window, label_entry:  630 633 633
# sequence, sequence+sliding_window, label_entry:  631 634 634
# sequence, sequence+sliding_window, label_entry:  632 635 635
# sequence, sequence+sliding_window, label_entry:  633 636 636
# sequence, sequence+sliding_window, label_entry:  634 637 637
# sequence, sequence+sliding_window, label_entry:  635 638 638
# sequence, sequence+sliding_window, label_entry:  636 639 639
# sequence, sequence+sliding_window, label_entry:  637 640 640
# sequence, sequence+sliding_window, label_entry:  638 641 641
# sequence, sequence+sliding_window, label_entry:  639 642 642
# sequence, sequence+sliding_window, label_entry:  640 643 643
# sequence, sequence+sliding_window, label_entry:  641 644 644
# sequence, sequence+sliding_window, label_entry:  642 645 645
# sequence, sequence+sliding_window, label_entry:  643 646 646
# sequence, sequence+sliding_window, label_entry:  644 647 647
# sequence, sequence+sliding_window, label_entry:  645 648 648
# sequence, sequence+sliding_window, label_entry:  646 649 649
# sequence, sequence+sliding_window, label_entry:  647 650 650
# sequence, sequence+sliding_window, label_entry:  648 651 651
# sequence, sequence+sliding_window, label_entry:  649 652 652
# sequence, sequence+sliding_window, label_entry:  650 653 653
# sequence, sequence+sliding_window, label_entry:  651 654 654
# sequence, sequence+sliding_window, label_entry:  652 655 655
# sequence, sequence+sliding_window, label_entry:  653 656 656
# sequence, sequence+sliding_window, label_entry:  654 657 657
# sequence, sequence+sliding_window, label_entry:  655 658 658
# sequence, sequence+sliding_window, label_entry:  656 659 659
# sequence, sequence+sliding_window, label_entry:  657 660 660
# sequence, sequence+sliding_window, label_entry:  658 661 661
# sequence, sequence+sliding_window, label_entry:  659 662 662
# sequence, sequence+sliding_window, label_entry:  660 663 663
# sequence, sequence+sliding_window, label_entry:  661 664 664
# sequence, sequence+sliding_window, label_entry:  662 665 665
# sequence, sequence+sliding_window, label_entry:  663 666 666
# sequence, sequence+sliding_window, label_entry:  664 667 667
# sequence, sequence+sliding_window, label_entry:  665 668 668
# sequence, sequence+sliding_window, label_entry:  666 669 669
# sequence, sequence+sliding_window, label_entry:  667 670 670
# sequence, sequence+sliding_window, label_entry:  668 671 671
# sequence, sequence+sliding_window, label_entry:  669 672 672
# sequence, sequence+sliding_window, label_entry:  670 673 673
# sequence, sequence+sliding_window, label_entry:  671 674 674
# sequence, sequence+sliding_window, label_entry:  672 675 675
# sequence, sequence+sliding_window, label_entry:  673 676 676
# sequence, sequence+sliding_window, label_entry:  674 677 677
# sequence, sequence+sliding_window, label_entry:  675 678 678
# sequence, sequence+sliding_window, label_entry:  676 679 679
# sequence, sequence+sliding_window, label_entry:  677 680 680
# sequence, sequence+sliding_window, label_entry:  678 681 681
# sequence, sequence+sliding_window, label_entry:  679 682 682
# sequence, sequence+sliding_window, label_entry:  680 683 683
# sequence, sequence+sliding_window, label_entry:  681 684 684
# sequence, sequence+sliding_window, label_entry:  682 685 685
# sequence, sequence+sliding_window, label_entry:  683 686 686
# sequence, sequence+sliding_window, label_entry:  684 687 687
# sequence, sequence+sliding_window, label_entry:  685 688 688
# sequence, sequence+sliding_window, label_entry:  686 689 689
# sequence, sequence+sliding_window, label_entry:  687 690 690
# sequence, sequence+sliding_window, label_entry:  688 691 691
# sequence, sequence+sliding_window, label_entry:  689 692 692
# sequence, sequence+sliding_window, label_entry:  690 693 693
# sequence, sequence+sliding_window, label_entry:  691 694 694
# sequence, sequence+sliding_window, label_entry:  692 695 695
# sequence, sequence+sliding_window, label_entry:  693 696 696
# sequence, sequence+sliding_window, label_entry:  694 697 697
# sequence, sequence+sliding_window, label_entry:  695 698 698
# sequence, sequence+sliding_window, label_entry:  696 699 699
# sequence, sequence+sliding_window, label_entry:  697 700 700
# sequence, sequence+sliding_window, label_entry:  698 701 701
# sequence, sequence+sliding_window, label_entry:  699 702 702
# sequence, sequence+sliding_window, label_entry:  700 703 703
# sequence, sequence+sliding_window, label_entry:  701 704 704
# sequence, sequence+sliding_window, label_entry:  702 705 705
# sequence, sequence+sliding_window, label_entry:  703 706 706
# sequence, sequence+sliding_window, label_entry:  704 707 707
# sequence, sequence+sliding_window, label_entry:  705 708 708
# sequence, sequence+sliding_window, label_entry:  706 709 709
# sequence, sequence+sliding_window, label_entry:  707 710 710
# sequence, sequence+sliding_window, label_entry:  708 711 711
# sequence, sequence+sliding_window, label_entry:  709 712 712
# sequence, sequence+sliding_window, label_entry:  710 713 713
# sequence, sequence+sliding_window, label_entry:  711 714 714
# sequence, sequence+sliding_window, label_entry:  712 715 715
# sequence, sequence+sliding_window, label_entry:  713 716 716
# sequence, sequence+sliding_window, label_entry:  714 717 717
# sequence, sequence+sliding_window, label_entry:  715 718 718
# sequence, sequence+sliding_window, label_entry:  716 719 719
# sequence, sequence+sliding_window, label_entry:  717 720 720
# sequence, sequence+sliding_window, label_entry:  718 721 721
# sequence, sequence+sliding_window, label_entry:  719 722 722
# sequence, sequence+sliding_window, label_entry:  720 723 723
# sequence, sequence+sliding_window, label_entry:  721 724 724
# sequence, sequence+sliding_window, label_entry:  722 725 725
# sequence, sequence+sliding_window, label_entry:  723 726 726
# sequence, sequence+sliding_window, label_entry:  724 727 727
# sequence, sequence+sliding_window, label_entry:  725 728 728
# sequence, sequence+sliding_window, label_entry:  726 729 729
# sequence, sequence+sliding_window, label_entry:  727 730 730
# sequence, sequence+sliding_window, label_entry:  728 731 731
# sequence, sequence+sliding_window, label_entry:  729 732 732
# sequence, sequence+sliding_window, label_entry:  730 733 733
# sequence, sequence+sliding_window, label_entry:  731 734 734
# sequence, sequence+sliding_window, label_entry:  732 735 735
# sequence, sequence+sliding_window, label_entry:  733 736 736
# sequence, sequence+sliding_window, label_entry:  734 737 737
# sequence, sequence+sliding_window, label_entry:  735 738 738
# sequence, sequence+sliding_window, label_entry:  736 739 739
# sequence, sequence+sliding_window, label_entry:  737 740 740
# sequence, sequence+sliding_window, label_entry:  738 741 741
# sequence, sequence+sliding_window, label_entry:  739 742 742
# sequence, sequence+sliding_window, label_entry:  740 743 743
# sequence, sequence+sliding_window, label_entry:  741 744 744
# sequence, sequence+sliding_window, label_entry:  742 745 745
# sequence, sequence+sliding_window, label_entry:  743 746 746
# sequence, sequence+sliding_window, label_entry:  744 747 747
# sequence, sequence+sliding_window, label_entry:  745 748 748
# sequence, sequence+sliding_window, label_entry:  746 749 749
# sequence, sequence+sliding_window, label_entry:  747 750 750
# sequence, sequence+sliding_window, label_entry:  748 751 751
# sequence, sequence+sliding_window, label_entry:  749 752 752
# sequence, sequence+sliding_window, label_entry:  750 753 753
# sequence, sequence+sliding_window, label_entry:  751 754 754
# sequence, sequence+sliding_window, label_entry:  752 755 755
# sequence, sequence+sliding_window, label_entry:  753 756 756
# sequence, sequence+sliding_window, label_entry:  754 757 757
# sequence, sequence+sliding_window, label_entry:  755 758 758
# sequence, sequence+sliding_window, label_entry:  756 759 759
# sequence, sequence+sliding_window, label_entry:  757 760 760
# sequence, sequence+sliding_window, label_entry:  758 761 761
# sequence, sequence+sliding_window, label_entry:  759 762 762
# sequence, sequence+sliding_window, label_entry:  760 763 763
# sequence, sequence+sliding_window, label_entry:  761 764 764
# sequence, sequence+sliding_window, label_entry:  762 765 765
# sequence, sequence+sliding_window, label_entry:  763 766 766
# sequence, sequence+sliding_window, label_entry:  764 767 767
# sequence, sequence+sliding_window, label_entry:  765 768 768
# sequence, sequence+sliding_window, label_entry:  766 769 769
# sequence, sequence+sliding_window, label_entry:  767 770 770
# sequence, sequence+sliding_window, label_entry:  768 771 771
# sequence, sequence+sliding_window, label_entry:  769 772 772
# sequence, sequence+sliding_window, label_entry:  770 773 773
# sequence, sequence+sliding_window, label_entry:  771 774 774
# sequence, sequence+sliding_window, label_entry:  772 775 775
# sequence, sequence+sliding_window, label_entry:  773 776 776
# sequence, sequence+sliding_window, label_entry:  774 777 777
# sequence, sequence+sliding_window, label_entry:  775 778 778
# sequence, sequence+sliding_window, label_entry:  776 779 779
# sequence, sequence+sliding_window, label_entry:  777 780 780
# sequence, sequence+sliding_window, label_entry:  778 781 781
# sequence, sequence+sliding_window, label_entry:  779 782 782
# sequence, sequence+sliding_window, label_entry:  780 783 783
# sequence, sequence+sliding_window, label_entry:  781 784 784
# sequence, sequence+sliding_window, label_entry:  782 785 785
# sequence, sequence+sliding_window, label_entry:  783 786 786
# sequence, sequence+sliding_window, label_entry:  784 787 787
# sequence, sequence+sliding_window, label_entry:  785 788 788
# sequence, sequence+sliding_window, label_entry:  786 789 789
# sequence, sequence+sliding_window, label_entry:  787 790 790
# sequence, sequence+sliding_window, label_entry:  788 791 791
# sequence, sequence+sliding_window, label_entry:  789 792 792
# sequence, sequence+sliding_window, label_entry:  790 793 793
# sequence, sequence+sliding_window, label_entry:  791 794 794
# sequence, sequence+sliding_window, label_entry:  792 795 795
# sequence, sequence+sliding_window, label_entry:  793 796 796
# sequence, sequence+sliding_window, label_entry:  794 797 797
# sequence, sequence+sliding_window, label_entry:  795 798 798
# sequence, sequence+sliding_window, label_entry:  796 799 799
# sequence, sequence+sliding_window, label_entry:  797 800 800
# sequence, sequence+sliding_window, label_entry:  798 801 801
# sequence, sequence+sliding_window, label_entry:  799 802 802
# sequence, sequence+sliding_window, label_entry:  800 803 803
# sequence, sequence+sliding_window, label_entry:  801 804 804
# sequence, sequence+sliding_window, label_entry:  802 805 805
# sequence, sequence+sliding_window, label_entry:  803 806 806
# sequence, sequence+sliding_window, label_entry:  804 807 807
# sequence, sequence+sliding_window, label_entry:  805 808 808
# sequence, sequence+sliding_window, label_entry:  806 809 809
# sequence, sequence+sliding_window, label_entry:  807 810 810
# sequence, sequence+sliding_window, label_entry:  808 811 811
# sequence, sequence+sliding_window, label_entry:  809 812 812
# sequence, sequence+sliding_window, label_entry:  810 813 813
# sequence, sequence+sliding_window, label_entry:  811 814 814
# sequence, sequence+sliding_window, label_entry:  812 815 815
# sequence, sequence+sliding_window, label_entry:  813 816 816
# sequence, sequence+sliding_window, label_entry:  814 817 817
# sequence, sequence+sliding_window, label_entry:  815 818 818
# sequence, sequence+sliding_window, label_entry:  816 819 819
# sequence, sequence+sliding_window, label_entry:  817 820 820
# sequence, sequence+sliding_window, label_entry:  818 821 821
# sequence, sequence+sliding_window, label_entry:  819 822 822
# sequence, sequence+sliding_window, label_entry:  820 823 823
# sequence, sequence+sliding_window, label_entry:  821 824 824
# sequence, sequence+sliding_window, label_entry:  822 825 825
# sequence, sequence+sliding_window, label_entry:  823 826 826
# sequence, sequence+sliding_window, label_entry:  824 827 827
# sequence, sequence+sliding_window, label_entry:  825 828 828
# sequence, sequence+sliding_window, label_entry:  826 829 829
# sequence, sequence+sliding_window, label_entry:  827 830 830
# sequence, sequence+sliding_window, label_entry:  828 831 831
# sequence, sequence+sliding_window, label_entry:  829 832 832
# sequence, sequence+sliding_window, label_entry:  830 833 833
# sequence, sequence+sliding_window, label_entry:  831 834 834
# sequence, sequence+sliding_window, label_entry:  832 835 835
# sequence, sequence+sliding_window, label_entry:  833 836 836
# sequence, sequence+sliding_window, label_entry:  834 837 837
# sequence, sequence+sliding_window, label_entry:  835 838 838
# sequence, sequence+sliding_window, label_entry:  836 839 839
# sequence, sequence+sliding_window, label_entry:  837 840 840
# sequence, sequence+sliding_window, label_entry:  838 841 841
# sequence, sequence+sliding_window, label_entry:  839 842 842
# sequence, sequence+sliding_window, label_entry:  840 843 843
# sequence, sequence+sliding_window, label_entry:  841 844 844
# sequence, sequence+sliding_window, label_entry:  842 845 845
# sequence, sequence+sliding_window, label_entry:  843 846 846
# LSTM input:  (844L, 3L, 23L)
# LSTM output:  (844L, 3L)

# %%
# Prepare test and train points
tot_points = return_data_matrix_lstm.shape[0]
train_points = int(np.floor(0.7*tot_points)) 
test_points = tot_points - train_points
print 'tot_points: ', tot_points, ' train_points: ', train_points, ' test_points: ', test_points

# Generate Train Sequence
x_train = np.copy(return_data_matrix_lstm[0:train_points + 1,:])
y_train = np.copy(return_label_matrix_lstm[0:train_points + 1,:])
# Generate Test Sequence
x_test = np.copy(return_data_matrix_lstm[train_points + 1:tot_points + 1 ,:])
y_test = np.copy(return_label_matrix_lstm[train_points + 1:tot_points + 1 ,:])

print 'x_train_shape: ', x_train.shape, ' y_train_shape: ', y_train.shape
print 'x_test_shape: ', x_test.shape, ' y_test_shape: ', y_test.shape
# Out:
# tot_points:  844  train_points:  590  test_points:  254
# x_train_shape:  (591L, 3L, 23L)  y_train_shape:  (591L, 3L)
# x_test_shape:  (253L, 3L, 23L)  y_test_shape:  (253L, 3L)

# %%
print train_points
# Out:
# 590

# %%
x_train.shape
# Out:
# (591L, 3L, 23L)

# %%
x_train.shape[2]
# Out:
# 23L

# %%
y_train.shape
# Out:
# (591L, 3L)

# %%
y_train.shape[1]
# Out:
# 3L

# %%
input_dim = x_train.shape[2] # Input vector dimension for LSTM (N x timesteps x dim of seq)
output_dim = y_train.shape[1] # Output dimension for LSTM (rainfall for t+1,t+2,t+3)

# create model
model = Sequential()
layers = [input_dim, 50, 100, output_dim]

model.add(LSTM(input_dim=layers[0],output_dim=layers[1],return_sequences=True))
model.add(Dropout(0.1))

model.add(LSTM(layers[2], return_sequences=False))
model.add(Dropout(0.1))

# model.add(LSTM(layers[3], return_sequences=True))
# model.add(Dropout(0.1))

# model.add(LSTM(layers[4], return_sequences=False))
# model.add(Dropout(0.1))

# model.add(Dense(output_dim=layers[5]))
# model.add(Activation("linear"))

model.add(Dense(output_dim=layers[3]))
model.add(Activation("linear"))

    
# compile model
# start = time.time()
model.compile(loss="mse", optimizer="rmsprop")
# print "Compilation Time : ", time.time() - start
# model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# filepath_savemodel = 'C:\\Shaukat\\code\\rainfall\\model_stored\\weights.{epoch:02d}-{val_loss:.2f}.h5'
filepath_savemodel = 'C://Shaukat//code//rainfall//model_stored/orford//model_lstm_orford_v1.h5'
# filepath_csvlogger = 'C:\\Shaukat\\code\\rainfall\\model_stored\\training_s2.log'

checkpointer = ModelCheckpoint(filepath_savemodel, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
# csv_logger = CSVLogger(filepath_csvlogger, separator=',', append=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0.001)

# history = model.fit(x_train, y_train, nb_epoch=1000, verbose=1, validation_data=(x_test, y_test), batch_size = 32, shuffle=True, callbacks=[checkpointer, csv_logger, reduce_lr])
# history = model.fit(x_train, y_train, nb_epoch=500, verbose=1, validation_data=(x_test, y_test), batch_size = train_points, shuffle=True, callbacks=[checkpointer, reduce_lr])
# history = model.fit(x_train, y_train, nb_epoch=100, verbose=1, validation_data=(x_test, y_test), batch_size = train_points, shuffle=True, callbacks=[checkpointer])
history = model.fit(x_train, y_train, nb_epoch=500, verbose=1, validation_data=(x_test, y_test), batch_size = 32, callbacks=[checkpointer, reduce_lr])
# Out:
# Train on 591 samples, validate on 253 samples
# Epoch 1/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.3227Epoch 00000: val_loss improved from inf to 0.07750, saving model to C://Shaukat//code//rainfall//model_stored/orford//model_lstm_orford_v1.h5
# 591/591 [==============================] - 0s - loss: 0.3163 - val_loss: 0.0775
# Epoch 2/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2919Epoch 00001: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2975 - val_loss: 0.0792
# Epoch 3/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2420Epoch 00002: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2909 - val_loss: 0.0796
# Epoch 4/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2389Epoch 00003: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2836 - val_loss: 0.0805
# Epoch 5/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2843Epoch 00004: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2780 - val_loss: 0.0785
# Epoch 6/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2755Epoch 00005: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2710 - val_loss: 0.0813
# Epoch 7/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2716Epoch 00006: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2654 - val_loss: 0.0802
# Epoch 8/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2726Epoch 00007: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2664 - val_loss: 0.0806
# Epoch 9/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2566Epoch 00008: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2594 - val_loss: 0.0830
# Epoch 10/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2554Epoch 00009: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2495 - val_loss: 0.0824
# Epoch 11/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2445Epoch 00010: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2415 - val_loss: 0.0822
# Epoch 12/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2401Epoch 00011: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2346 - val_loss: 0.0839
# Epoch 13/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2174Epoch 00012: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2344 - val_loss: 0.0857
# Epoch 14/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2271Epoch 00013: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2224 - val_loss: 0.0884
# Epoch 15/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2226Epoch 00014: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2233 - val_loss: 0.0893
# Epoch 16/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1943Epoch 00015: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2113 - val_loss: 0.0878
# Epoch 17/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.2043Epoch 00016: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1997 - val_loss: 0.0910
# Epoch 18/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.2075Epoch 00017: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.2052 - val_loss: 0.0895
# Epoch 19/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1744Epoch 00018: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1881 - val_loss: 0.0924
# Epoch 20/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1899Epoch 00019: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1872 - val_loss: 0.0930
# Epoch 21/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.1679Epoch 00020: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1666 - val_loss: 0.0908
# Epoch 22/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1746Epoch 00021: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1706 - val_loss: 0.0896
# Epoch 23/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1717Epoch 00022: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1677 - val_loss: 0.0896
# Epoch 24/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1759Epoch 00023: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1784 - val_loss: 0.0908
# Epoch 25/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1602Epoch 00024: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1568 - val_loss: 0.0946
# Epoch 26/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1432Epoch 00025: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1402 - val_loss: 0.0940
# Epoch 27/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1310Epoch 00026: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1332 - val_loss: 0.0929
# Epoch 28/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.1496Epoch 00027: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1418 - val_loss: 0.1006
# Epoch 29/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1302Epoch 00028: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1278 - val_loss: 0.0929
# Epoch 30/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1299Epoch 00029: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1396 - val_loss: 0.0975
# Epoch 31/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.1309Epoch 00030: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1222 - val_loss: 0.0939
# Epoch 32/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1138Epoch 00031: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1125 - val_loss: 0.0958
# Epoch 33/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1129Epoch 00032: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1112 - val_loss: 0.0943
# Epoch 34/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1051Epoch 00033: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 35/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0992Epoch 00034: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1016 - val_loss: 0.0945
# Epoch 36/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.1050Epoch 00035: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1090 - val_loss: 0.1017
# Epoch 37/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.1070Epoch 00036: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.1148 - val_loss: 0.1028
# Epoch 38/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0939Epoch 00037: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0893 - val_loss: 0.0974
# Epoch 39/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0946Epoch 00038: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0932 - val_loss: 0.0996
# Epoch 40/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0832Epoch 00039: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0819 - val_loss: 0.1004
# Epoch 41/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0611Epoch 00040: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0817 - val_loss: 0.1077
# Epoch 42/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0885Epoch 00041: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0885 - val_loss: 0.0983
# Epoch 43/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0755Epoch 00042: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0773 - val_loss: 0.1028
# Epoch 44/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0726Epoch 00043: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0761 - val_loss: 0.1024
# Epoch 45/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0821Epoch 00044: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0796 - val_loss: 0.1052
# Epoch 46/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0576Epoch 00045: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0689 - val_loss: 0.1001
# Epoch 47/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0762Epoch 00046: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0768 - val_loss: 0.0984
# Epoch 48/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0637Epoch 00047: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0640 - val_loss: 0.1066
# Epoch 49/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0633Epoch 00048: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0672 - val_loss: 0.1058
# Epoch 50/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0606Epoch 00049: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0607 - val_loss: 0.1041
# Epoch 51/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0625Epoch 00050: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0623 - val_loss: 0.1020
# Epoch 52/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0612Epoch 00051: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0622 - val_loss: 0.0979
# Epoch 53/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0585Epoch 00052: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0576 - val_loss: 0.1020
# Epoch 54/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0627Epoch 00053: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0616 - val_loss: 0.1003
# Epoch 55/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0595Epoch 00054: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0587 - val_loss: 0.1040
# Epoch 56/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0468Epoch 00055: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0553 - val_loss: 0.1042
# Epoch 57/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0437Epoch 00056: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0432 - val_loss: 0.1029
# Epoch 58/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0465Epoch 00057: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0523 - val_loss: 0.1052
# Epoch 59/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0479Epoch 00058: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0469 - val_loss: 0.1036
# Epoch 60/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0495Epoch 00059: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0489 - val_loss: 0.1031
# Epoch 61/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0499Epoch 00060: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0473 - val_loss: 0.1003
# Epoch 62/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0442Epoch 00061: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0472 - val_loss: 0.0977
# Epoch 63/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0460Epoch 00062: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0444 - val_loss: 0.1061
# Epoch 64/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0442Epoch 00063: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0447 - val_loss: 0.1080
# Epoch 65/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0439Epoch 00064: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0431 - val_loss: 0.0999
# Epoch 66/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0384Epoch 00065: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0382 - val_loss: 0.1026
# Epoch 67/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0403Epoch 00066: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0385 - val_loss: 0.0955
# Epoch 68/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0376Epoch 00067: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0432 - val_loss: 0.1089
# Epoch 69/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0406Epoch 00068: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0388 - val_loss: 0.0953
# Epoch 70/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0361Epoch 00069: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0362 - val_loss: 0.1012
# Epoch 71/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0318Epoch 00070: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0361 - val_loss: 0.1004
# Epoch 72/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0383Epoch 00071: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0380 - val_loss: 0.0956
# Epoch 73/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0406Epoch 00072: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0412 - val_loss: 0.0946
# Epoch 74/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0340Epoch 00073: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0341 - val_loss: 0.0985
# Epoch 75/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0372Epoch 00074: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0369 - val_loss: 0.0970
# Epoch 76/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0319Epoch 00075: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0329 - val_loss: 0.1007
# Epoch 77/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0394Epoch 00076: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0370 - val_loss: 0.1000
# Epoch 78/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0326Epoch 00077: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0320 - val_loss: 0.0958
# Epoch 79/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0285Epoch 00078: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0307 - val_loss: 0.0981
# Epoch 80/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0319Epoch 00079: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0309 - val_loss: 0.0958
# Epoch 81/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0371Epoch 00080: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0354 - val_loss: 0.0986
# Epoch 82/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0312Epoch 00081: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0310 - val_loss: 0.0989
# Epoch 83/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0288Epoch 00082: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0303 - val_loss: 0.0968
# Epoch 84/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0309Epoch 00083: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0300 - val_loss: 0.0914
# Epoch 85/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0348Epoch 00084: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0336 - val_loss: 0.0966
# Epoch 86/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0291Epoch 00085: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0277 - val_loss: 0.0975
# Epoch 87/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0310Epoch 00086: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0313 - val_loss: 0.0939
# Epoch 88/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0336Epoch 00087: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0347 - val_loss: 0.0958
# Epoch 89/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0305Epoch 00088: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0301 - val_loss: 0.0909
# Epoch 90/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0292Epoch 00089: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0288 - val_loss: 0.0942
# Epoch 91/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0274Epoch 00090: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0281 - val_loss: 0.0888
# Epoch 92/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0252Epoch 00091: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0262 - val_loss: 0.0893
# Epoch 93/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0320Epoch 00092: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0308 - val_loss: 0.0972
# Epoch 94/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0275Epoch 00093: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0292 - val_loss: 0.0976
# Epoch 95/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0267Epoch 00094: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0253 - val_loss: 0.0943
# Epoch 96/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0288Epoch 00095: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0281 - val_loss: 0.0959
# Epoch 97/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0260Epoch 00096: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0275 - val_loss: 0.0948
# Epoch 98/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0267Epoch 00097: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0263 - val_loss: 0.1000
# Epoch 99/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0250Epoch 00098: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0246 - val_loss: 0.0984
# Epoch 100/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0234Epoch 00099: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0236 - val_loss: 0.0933
# Epoch 101/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0237Epoch 00100: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0233 - val_loss: 0.0924
# Epoch 102/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0281Epoch 00101: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0278 - val_loss: 0.0908
# Epoch 103/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0302Epoch 00102: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0299 - val_loss: 0.0969
# Epoch 104/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0222Epoch 00103: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0219 - val_loss: 0.0962
# Epoch 105/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0251Epoch 00104: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0252 - val_loss: 0.0954
# Epoch 106/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0210Epoch 00105: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0209 - val_loss: 0.0907
# Epoch 107/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0251Epoch 00106: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0246 - val_loss: 0.0932
# Epoch 108/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0268Epoch 00107: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0268 - val_loss: 0.0917
# Epoch 109/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0231Epoch 00108: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0225 - val_loss: 0.0974
# Epoch 110/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0259Epoch 00109: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0254 - val_loss: 0.0985
# Epoch 111/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0232Epoch 00110: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0232 - val_loss: 0.0935
# Epoch 112/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0260Epoch 00111: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0249 - val_loss: 0.0951
# Epoch 113/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0233Epoch 00112: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0231 - val_loss: 0.0949
# Epoch 114/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0223Epoch 00113: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0221 - val_loss: 0.0901
# Epoch 115/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0195Epoch 00114: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0191 - val_loss: 0.0912
# Epoch 116/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0214Epoch 00115: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0204 - val_loss: 0.0871
# Epoch 117/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0213Epoch 00116: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0209 - val_loss: 0.0968
# Epoch 118/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0232Epoch 00117: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0228 - val_loss: 0.0903
# Epoch 119/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0202Epoch 00118: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0202 - val_loss: 0.0924
# Epoch 120/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0229Epoch 00119: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0225 - val_loss: 0.0941
# Epoch 121/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0188Epoch 00120: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0186 - val_loss: 0.0926
# Epoch 122/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0283Epoch 00121: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0278 - val_loss: 0.0923
# Epoch 123/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0155Epoch 00122: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0189 - val_loss: 0.0923
# Epoch 124/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0213Epoch 00123: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0209 - val_loss: 0.0869
# Epoch 125/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0181Epoch 00124: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0178 - val_loss: 0.0955
# Epoch 126/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0259Epoch 00125: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0244 - val_loss: 0.0919
# Epoch 127/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0170Epoch 00126: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0167 - val_loss: 0.0874
# Epoch 128/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0177Epoch 00127: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0177 - val_loss: 0.0918
# Epoch 129/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0227Epoch 00128: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0226 - val_loss: 0.0908
# Epoch 130/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0210Epoch 00129: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0212 - val_loss: 0.0936
# Epoch 131/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0148Epoch 00130: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0146 - val_loss: 0.0875
# Epoch 132/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0209Epoch 00131: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0198 - val_loss: 0.0933
# Epoch 133/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0158Epoch 00132: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0175 - val_loss: 0.0849
# Epoch 134/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0207Epoch 00133: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0206 - val_loss: 0.0918
# Epoch 135/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0172Epoch 00134: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0167 - val_loss: 0.0902
# Epoch 136/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0173Epoch 00135: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0175 - val_loss: 0.0898
# Epoch 137/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0170Epoch 00136: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0168 - val_loss: 0.0951
# Epoch 138/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0172Epoch 00137: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0170 - val_loss: 0.0896
# Epoch 139/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0166Epoch 00138: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0173 - val_loss: 0.0982
# Epoch 140/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0215Epoch 00139: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0211 - val_loss: 0.0963
# Epoch 141/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0146Epoch 00140: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0153 - val_loss: 0.0890
# Epoch 142/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0185Epoch 00141: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0189 - val_loss: 0.0978
# Epoch 143/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0172Epoch 00142: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0178 - val_loss: 0.0885
# Epoch 144/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0178Epoch 00143: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0177 - val_loss: 0.0920
# Epoch 145/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0158Epoch 00144: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0155 - val_loss: 0.0951
# Epoch 146/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0147Epoch 00145: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0147 - val_loss: 0.0955
# Epoch 147/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0127Epoch 00146: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0125 - val_loss: 0.0907
# Epoch 148/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0142Epoch 00147: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0147 - val_loss: 0.0935
# Epoch 149/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0130Epoch 00148: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0130 - val_loss: 0.0972
# Epoch 150/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0130Epoch 00149: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0129 - val_loss: 0.0919
# Epoch 151/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0157Epoch 00150: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0167 - val_loss: 0.0978
# Epoch 152/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0123Epoch 00151: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0123 - val_loss: 0.0917
# Epoch 153/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0127Epoch 00152: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0124 - val_loss: 0.0926
# Epoch 154/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0156Epoch 00153: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0159 - val_loss: 0.1083
# Epoch 155/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0134Epoch 00154: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0135 - val_loss: 0.0926
# Epoch 156/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0111Epoch 00155: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0116 - val_loss: 0.0891
# Epoch 157/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0146Epoch 00156: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0147 - val_loss: 0.0994
# Epoch 158/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0113Epoch 00157: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0112 - val_loss: 0.0896
# Epoch 159/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0161Epoch 00158: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0158 - val_loss: 0.0923
# Epoch 160/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0139Epoch 00159: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0138 - val_loss: 0.0927
# Epoch 161/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0128Epoch 00160: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0141 - val_loss: 0.0934
# Epoch 162/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0093Epoch 00161: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0112 - val_loss: 0.0946
# Epoch 163/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0122Epoch 00162: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0120 - val_loss: 0.1015
# Epoch 164/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0139Epoch 00163: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0137 - val_loss: 0.0958
# Epoch 165/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0119Epoch 00164: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0125 - val_loss: 0.0936
# Epoch 166/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0123Epoch 00165: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0135 - val_loss: 0.0952
# Epoch 167/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0157Epoch 00166: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0155 - val_loss: 0.0963
# Epoch 168/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0135Epoch 00167: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0130 - val_loss: 0.0974
# Epoch 169/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0136Epoch 00168: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0133 - val_loss: 0.0881
# Epoch 170/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0133Epoch 00169: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0131 - val_loss: 0.0912
# Epoch 171/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0151Epoch 00170: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0144 - val_loss: 0.0939
# Epoch 172/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0112Epoch 00171: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0110 - val_loss: 0.0902
# Epoch 173/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0101Epoch 00172: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0102 - val_loss: 0.0945
# Epoch 174/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0140Epoch 00173: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0138 - val_loss: 0.0895
# Epoch 175/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0161Epoch 00174: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0159 - val_loss: 0.0876
# Epoch 176/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0129Epoch 00175: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0129 - val_loss: 0.0917
# Epoch 177/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0130Epoch 00176: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0127 - val_loss: 0.0872
# Epoch 178/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0113Epoch 00177: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0108 - val_loss: 0.0937
# Epoch 179/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0099Epoch 00178: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0142 - val_loss: 0.0901
# Epoch 180/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0112Epoch 00179: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0115 - val_loss: 0.0878
# Epoch 181/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0128Epoch 00180: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0128 - val_loss: 0.0905
# Epoch 182/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0121Epoch 00181: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0119 - val_loss: 0.0922
# Epoch 183/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0145Epoch 00182: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0144 - val_loss: 0.0886
# Epoch 184/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0091Epoch 00183: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0090 - val_loss: 0.0889
# Epoch 185/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0112Epoch 00184: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0106 - val_loss: 0.0922
# Epoch 186/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0129Epoch 00185: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0126 - val_loss: 0.0867
# Epoch 187/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0104Epoch 00186: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0104 - val_loss: 0.0928
# Epoch 188/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0161Epoch 00187: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0152 - val_loss: 0.0954
# Epoch 189/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0089Epoch 00188: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0906
# Epoch 190/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0133Epoch 00189: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0127 - val_loss: 0.0929
# Epoch 191/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0096Epoch 00190: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0101 - val_loss: 0.0951
# Epoch 192/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0125Epoch 00191: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0123 - val_loss: 0.0975
# Epoch 193/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0145Epoch 00192: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0142 - val_loss: 0.0893
# Epoch 194/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0132Epoch 00193: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0130 - val_loss: 0.0905
# Epoch 195/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0103Epoch 00194: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0102 - val_loss: 0.0960
# Epoch 196/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0139Epoch 00195: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0136 - val_loss: 0.0947
# Epoch 197/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0082Epoch 00196: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0084 - val_loss: 0.0917
# Epoch 198/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0100Epoch 00197: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0099 - val_loss: 0.0921
# Epoch 199/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0099Epoch 00198: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0095 - val_loss: 0.0898
# Epoch 200/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0145Epoch 00199: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0143 - val_loss: 0.0921
# Epoch 201/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0116Epoch 00200: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0113 - val_loss: 0.0941
# Epoch 202/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0109Epoch 00201: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0112 - val_loss: 0.0890
# Epoch 203/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0121Epoch 00202: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0119 - val_loss: 0.0960
# Epoch 204/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0101Epoch 00203: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0102 - val_loss: 0.0929
# Epoch 205/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0130Epoch 00204: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0132 - val_loss: 0.0904
# Epoch 206/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0095Epoch 00205: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0113 - val_loss: 0.0937
# Epoch 207/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0103Epoch 00206: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0100 - val_loss: 0.0944
# Epoch 208/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0113Epoch 00207: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0110 - val_loss: 0.0905
# Epoch 209/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0095Epoch 00208: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0093 - val_loss: 0.0904
# Epoch 210/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0145Epoch 00209: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0140 - val_loss: 0.0924
# Epoch 211/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0108Epoch 00210: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0106 - val_loss: 0.0908
# Epoch 212/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0091Epoch 00211: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0089 - val_loss: 0.0904
# Epoch 213/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0090Epoch 00212: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0979
# Epoch 214/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0120Epoch 00213: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0122 - val_loss: 0.0893
# Epoch 215/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0089Epoch 00214: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0882
# Epoch 216/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0117Epoch 00215: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0115 - val_loss: 0.0911
# Epoch 217/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0093Epoch 00216: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0088 - val_loss: 0.0900
# Epoch 218/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0095Epoch 00217: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0093 - val_loss: 0.0879
# Epoch 219/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0093Epoch 00218: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0095 - val_loss: 0.0875
# Epoch 220/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0106Epoch 00219: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0105 - val_loss: 0.0934
# Epoch 221/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0090Epoch 00220: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0092 - val_loss: 0.0881
# Epoch 222/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0095Epoch 00221: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0095 - val_loss: 0.0910
# Epoch 223/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0093Epoch 00222: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0092 - val_loss: 0.0949
# Epoch 224/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0090Epoch 00223: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0881
# Epoch 225/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0091Epoch 00224: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0092 - val_loss: 0.0905
# Epoch 226/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0118Epoch 00225: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0114 - val_loss: 0.0912
# Epoch 227/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0079Epoch 00226: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0083 - val_loss: 0.0901
# Epoch 228/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0106Epoch 00227: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0104 - val_loss: 0.0943
# Epoch 229/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0131Epoch 00228: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0128 - val_loss: 0.0956
# Epoch 230/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0091Epoch 00229: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0091 - val_loss: 0.0909
# Epoch 231/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0081Epoch 00230: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0080 - val_loss: 0.0866
# Epoch 232/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0080Epoch 00231: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0097 - val_loss: 0.0929
# Epoch 233/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0111Epoch 00232: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0106 - val_loss: 0.0891
# Epoch 234/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0072Epoch 00233: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0082 - val_loss: 0.0963
# Epoch 235/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0097Epoch 00234: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0093 - val_loss: 0.0948
# Epoch 236/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0108Epoch 00235: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0103 - val_loss: 0.0925
# Epoch 237/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0093Epoch 00236: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0109 - val_loss: 0.0895
# Epoch 238/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0070Epoch 00237: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0080 - val_loss: 0.0911
# Epoch 239/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0099Epoch 00238: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0097 - val_loss: 0.0867
# Epoch 240/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0076Epoch 00239: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0078 - val_loss: 0.0913
# Epoch 241/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0079Epoch 00240: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0863
# Epoch 242/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0070Epoch 00241: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0087 - val_loss: 0.0935
# Epoch 243/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0086Epoch 00242: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0876
# Epoch 244/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0079Epoch 00243: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0873
# Epoch 245/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0067Epoch 00244: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0068 - val_loss: 0.0902
# Epoch 246/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0106Epoch 00245: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0103 - val_loss: 0.0890
# Epoch 247/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0080Epoch 00246: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0082 - val_loss: 0.0866
# Epoch 248/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0121Epoch 00247: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0113 - val_loss: 0.0892
# Epoch 249/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0097Epoch 00248: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0096 - val_loss: 0.0850
# Epoch 250/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0077Epoch 00249: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0896
# Epoch 251/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0114Epoch 00250: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0107 - val_loss: 0.0885
# Epoch 252/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0081Epoch 00251: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0903
# Epoch 253/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0080Epoch 00252: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0080 - val_loss: 0.0916
# Epoch 254/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0099Epoch 00253: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0098 - val_loss: 0.0890
# Epoch 255/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0077Epoch 00254: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0902
# Epoch 256/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0092Epoch 00255: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0089 - val_loss: 0.0907
# Epoch 257/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0077Epoch 00256: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0073 - val_loss: 0.0883
# Epoch 258/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0079Epoch 00257: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0077 - val_loss: 0.0889
# Epoch 259/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0073Epoch 00258: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0074 - val_loss: 0.0891
# Epoch 260/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0073Epoch 00259: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0082 - val_loss: 0.0886
# Epoch 261/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0073Epoch 00260: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0072 - val_loss: 0.0913
# Epoch 262/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0077Epoch 00261: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0075 - val_loss: 0.0878
# Epoch 263/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0106Epoch 00262: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0104 - val_loss: 0.0876
# Epoch 264/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0097Epoch 00263: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0096 - val_loss: 0.0887
# Epoch 265/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0080Epoch 00264: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0079 - val_loss: 0.0917
# Epoch 266/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0083Epoch 00265: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0087 - val_loss: 0.0885
# Epoch 267/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0081Epoch 00266: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0081 - val_loss: 0.0918
# Epoch 268/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0101Epoch 00267: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0100 - val_loss: 0.0920
# Epoch 269/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0096Epoch 00268: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0095 - val_loss: 0.0892
# Epoch 270/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0080Epoch 00269: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0076 - val_loss: 0.0865
# Epoch 271/500
# 544/591 [==========================>...] - ETA: 0s - loss: 0.0094Epoch 00270: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0112 - val_loss: 0.0895
# Epoch 272/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0058Epoch 00271: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0057 - val_loss: 0.0918
# Epoch 273/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0078Epoch 00272: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0076 - val_loss: 0.0916
# Epoch 274/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0077Epoch 00273: val_loss did not improve
# 591/591 [==============================] - 0s - loss: 0.0076 - val_loss: 0.0863
# Epoch 275/500
# 576/591 [============================>.] - ETA: 0s - loss: 0.0100

# %%
# del model

# %%
# Load best model
# model = load_model('C://Shaukat//code//rainfall//model_stored//merimbula//model_lstm_v1_merimbula.h5')
model.evaluate(x_test,y_test)
# Out:
# 224/253 [=========================>....] - ETA: 0s
# 0.091782551841339169

# %%
check_pred = model.predict(x_test)

# %%
check_pred[0:10]
# Out:
# array([[ 0.01409834, -0.06843444,  0.15986508],
#        [ 0.0405205 , -0.01267075,  0.24625464],
#        [ 0.01837153,  0.00134277,  0.05640363],
#        [ 0.00311438, -0.00252236,  0.01739329],
#        [-0.0040691 , -0.00202661,  0.01216253],
#        [ 0.03529597,  0.00895668,  0.02068807],
#        [ 0.01238772, -0.00319692, -0.00661755],
#        [ 0.01655137,  0.00662374, -0.01043028],
#        [ 0.01801096,  0.01577237,  0.0020013 ],
#        [ 0.00449384,  0.00440084, -0.00147292]], dtype=float32)

# %%
vec_test = y_test.flatten()
vec_test = vec_test.reshape((len(vec_test),1))
print vec_test.shape
print 'total test points: ', vec_test.shape[0]

predictions = model.predict(x_test)
pred_vec = predictions.flatten()
pred_vec = pred_vec.reshape((len(pred_vec),1))
print pred_vec.shape
# Out:
# (759L, 1L)
# total test points:  759
# (759L, 1L)

# %%
# Preprocess block
# threshold = 1.0
# preproc_y = deepcopy(pred_vec)
# preproc_y[preproc_y<=threshold] = 0.0

# %%
# For plot
time_index = np.arange(0,vec_test.shape[0],1)
time_index = time_index.reshape(((len(time_index),1)))

plt_lower_limit = 0
plt_upper_limit = 759

plt.figure(figsize=(25,8))

# plot

# Full plot
# plt.plot(time_index,vec_test,label="GroundTruth",color='b')
# plt.plot(time_index,pred_vec,label="Prediction",color='g')

# Unpreprocessed Plot
plt.plot(time_index[plt_lower_limit:plt_upper_limit],vec_test[plt_lower_limit:plt_upper_limit],label="GroundTruth",color='b')
plt.plot(time_index[plt_lower_limit:plt_upper_limit],pred_vec[plt_lower_limit:plt_upper_limit],label="Prediction",color='g')

# Preprocessed Plot
# plt.plot(time_index[plt_lower_limit:plt_upper_limit],vec_test[plt_lower_limit:plt_upper_limit],label="GroundTruth",color='b')
# plt.plot(time_index[plt_lower_limit:plt_upper_limit],preproc_y[plt_lower_limit:plt_upper_limit],label="Prediction",color='g')

plt.xlabel('Time')
plt.ylabel('Rainfall prediction in mm')
plt.legend()
plt.title('Groundtruth and Predicted Rainfall per hour')
# img_filename = 'C:\\Users\\ShaukatAbidi\\Documents\\shaukat_python_progs\\learning\\time_series\\feed_forward_nn\\models\\s7_images\\'+str(test_ex)+'.png'
# plt.savefig(img_filename, bbox_inches='tight')
# plt.clf()

# %%
vec_train = y_train.flatten()
vec_train = vec_train.reshape((len(vec_train),1))
print vec_train.shape
print 'total train points: ', vec_train.shape[0]

pred_on_gt = model.predict(x_train)
pred_on_gt_vec = pred_on_gt.flatten()
pred_on_gt_vec = pred_on_gt_vec.reshape((len(pred_on_gt_vec),1))
print pred_on_gt_vec.shape
# Out:
# (1773L, 1L)
# total train points:  1773
# (1773L, 1L)

# %%
# For plot
time_index = np.arange(0,vec_train.shape[0],1)
time_index = time_index.reshape(((len(time_index),1)))

plt_lower_limit = 0
plt_upper_limit = 1500

plt.figure(figsize=(25,8))

# plot

# Full plot
# plt.plot(time_index,vec_test,label="GroundTruth",color='b')
# plt.plot(time_index,pred_vec,label="Prediction",color='g')

# Unpreprocessed Plot
plt.plot(time_index[plt_lower_limit:plt_upper_limit],vec_train[plt_lower_limit:plt_upper_limit],label="GroundTruth",color='b')
plt.plot(time_index[plt_lower_limit:plt_upper_limit],pred_on_gt_vec[plt_lower_limit:plt_upper_limit],label="Prediction",color='g')

# Preprocessed Plot
# plt.plot(time_index[plt_lower_limit:plt_upper_limit],vec_test[plt_lower_limit:plt_upper_limit],label="GroundTruth",color='b')
# plt.plot(time_index[plt_lower_limit:plt_upper_limit],preproc_y[plt_lower_limit:plt_upper_limit],label="Prediction",color='g')

plt.xlabel('Time')
plt.ylabel('Rainfall prediction in mm')
plt.legend()
plt.title('Groundtruth and Predicted Rainfall per hour')
# img_filename = 'C:\\Users\\ShaukatAbidi\\Documents\\shaukat_python_progs\\learning\\time_series\\feed_forward_nn\\models\\s7_images\\'+str(test_ex)+'.png'
# plt.savefig(img_filename, bbox_inches='tight')
# plt.clf()

# %%
model.weights

# %%
x_train[1]
